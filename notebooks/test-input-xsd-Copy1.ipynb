# %% [markdown]
# # Test imported XSD files – Issue #3
#
# This notebook performs the following tasks:
#
# - Extracts the ZIP archive containing XSD schemas
# - Locates the main `.xsd` file with `<xs:import>` declarations (`input_data.xsd` or `index/index_data.xsd`)
# - Verifies:
#   1. That all imported files actually exist in the extracted folder
#   2. That all existing `.xsd` files are actually imported by someone

# %% [markdown]
# ### Import needed libraries
#
# - `zipfile` – for working with ZIP archives
# - `json` – for working with jsons
# - `xmlschema` – to read and validate XSD files (`pip install xmlschema`)
# - `pandas` – for working with tables and dataframes (`pip install pandas`)
# - `lxml.etree` – to parse and read XML/XSD structure (`pip install lxml`)
# - `pathlib.Path` – for path handling
#
# Make sure to install missing ones using `pip` if needed.

# %%
import zipfile
import tempfile
import json
import xmlschema
import pandas as pd
from lxml import etree
from pathlib import Path

# %% [markdown]
# ### Set paths for input ZIP and output folder
#
# This cell sets:
# - `input_zip_path`: path to the input ZIP file with XSDs
# - `output_path`: where to extract files
#
# If the folder doesn't exist, it will be created.

# %%
# Define the path to the input zip file and output directory
input_zip_path = Path("../tests/data/JVF_DTM_143_XSD.zip")
output_path = Path("../tests/output/JVF_DTM_143_XSD")

# Create the output directory if it doesn't exist
output_path.mkdir(parents=True, exist_ok=True)

# %% [markdown]
# ### Unzip the input file
#
# Extracts the ZIP archive to the output folder and prints the extracted file names.

# %%
# Extract the zip file
with zipfile.ZipFile(input_zip_path, 'r') as zip_ref:
    zip_ref.extractall(output_path)

# Show extracted files
print(f"Extracted to: {output_path}")
print(sorted(f.name for f in output_path.iterdir()))
# Out:
# Extracted to: ..\tests\output\JVF_DTM_143_XSD
# ['xsd']

# %% [markdown]
# ### Load and parse XSD files
#
# Defines a function that finds all `.xsd` files in the folder, parses them into XML trees, and returns a list of (file name, XML root element) pairs.

# %%
# Set the path to the folder with extracted XSD files
xsd_dir = output_path / "xsd"

def load_xsd_files(directory):
    """Load all XSD files from the given directory and parse them into XML trees.
    
    Args:
        directory (Path): Base directory to search for .xsd files.

    Returns:
        list of (filename, XML root element) tuples.
    """
    
    # Initialize an empty list to store parsed XSD file information
    xsd_files = []
    
    # Recursively find all .xsd files
    for path in directory.rglob("*.xsd"):
        try:
            # Parse the file into an XML tree
            tree = etree.parse(str(path))
    
            # Add the file name and root element to the list
            xsd_files.append((path.name, tree.getroot()))
    
        except etree.XMLSyntaxError as e:
            # Handle invalid XML syntax
            print(f"[XMLSyntaxError] Skipping {path.name}: {e}")
    
        except Exception as e:
            #  Handle all unexpected errors
            print(f"[UnexpectedError] Could not process {path.name}: {e}")
            raise  # Re-raise the exception

    return xsd_files

# Call the function to load and parse the XSD files
xsd_files = load_xsd_files(xsd_dir)

# %% [markdown]
# ### Create summary table of XSD files
#
# Builds a simple table showing each XSD file's name, root tag, and number of elements.

# %%
# xsd_files to store the full Paths
xsd_files = []
for path in output_path.rglob("*.xsd"):
    # parse and get root
    tree = etree.parse(str(path))        
    root = tree.getroot()
    # store the absolute Path and its root element
    xsd_files.append((path, root))

# Build the summary using true relative paths
summary = []
for path, root in xsd_files:
    # compute the path relative to the root XSD folder
    rel = path.relative_to(output_path)  

    summary.append({
        "File Name":          path.name,      
        "Relative Path":      rel.as_posix(), 
        "Root Tag":           root.tag,       
        "Number of Elements": len(root)       
    })

# Create and display the DataFrame
df_summary = pd.DataFrame(summary)
df_summary
# Out:
#                     File Name                        Relative Path  \
# 0                atributy.xsd              xsd/common/atributy.xsd
# 1                  common.xsd                xsd/common/common.xsd
# 2    doprovodne_informace.xsd  xsd/common/doprovodne_informace.xsd
# 3                 extenze.xsd               xsd/common/extenze.xsd
# 4                  servis.xsd                xsd/common/servis.xsd
# ..                        ...                                  ...
# 442    spatialReferencing.xsd   xsd/ext/gsr/spatialReferencing.xsd
# 443              geometry.xsd             xsd/ext/gss/geometry.xsd
# 444                   gss.xsd                  xsd/ext/gss/gss.xsd
# 445                   gts.xsd                  xsd/ext/gts/gts.xsd
# 446       temporalObjects.xsd      xsd/ext/gts/temporalObjects.xsd
#
#                                      Root Tag  Number of Elements
# 0    {http://www.w3.org/2001/XMLSchema}schema                 185
# 1    {http://www.w3.org/2001/XMLSchema}schema                   4
# 2    {http://www.w3.org/2001/XMLSchema}schema                  29
# 3    {http://www.w3.org/2001/XMLSchema}schema                   1
# 4    {http://www.w3.org/2001/XMLSchema}schema                   1
# ..                                        ...                 ...
# 442  {http://www.w3.org/2001/XMLSchema}schema                  14
# 443  {http://www.w3.org/2001/XMLSchema}schema                  19
# 444  {http://www.w3.org/2001/XMLSchema}schema                   7
# 445  {http://www.w3.org/2001/XMLSchema}schema                   7
# 446  {http://www.w3.org/2001/XMLSchema}schema                  19
#
# [447 rows x 4 columns]

# %% [markdown]
# ### Locate the main `.xsd` file
#
# This step searches for the main file that contains `<xs:import>` declarations.
# - It first looks for `input_data.xsd` in any folder
# - If not found, it tries `index/index_data.xsd`
# - If neither is found, an error is raised

# %% [markdown]
# Collect and Display XSD File Paths from file

# %%
# Attempt to locate the main XSD file
xsd_path = None

# Search for 'input_data.xsd' or 'index_data.xsd' under output_path
candidates = list(output_path.rglob("input_data.xsd")) + list(output_path.rglob("index_data.xsd"))

if candidates:
    xsd_path = candidates[0]
    print("Found main XSD file:", xsd_path.relative_to(output_path))
else:
    raise FileNotFoundError("Neither 'input_data.xsd' nor 'index_data.xsd' was found.")
# Out:
# Found main XSD file: xsd\index\index_data.xsd

# %%
# Verify that xsd_path is set
if xsd_path is None:
    raise ValueError("xsd_path is not set. Cannot continue.")

# Parse the main XSD file and retrieve its root element
tree = etree.parse(str(xsd_path))
root = tree.getroot()

# Define the namespace mapping for XSD elements
xs_ns = {"xs": "http://www.w3.org/2001/XMLSchema"}

# Collect all <xs:import> and <xs:include> elements and their types
records = []

# Find and record each import's schemaLocation
for el in root.findall(".//xs:import", namespaces=xs_ns):
    loc = el.get("schemaLocation")
    if loc:
        records.append({"schemaLocation": loc, "type": "import"})

# Find and record each include's schemaLocation
for el in root.findall(".//xs:include", namespaces=xs_ns):
    loc = el.get("schemaLocation")
    if loc:
        records.append({"schemaLocation": loc, "type": "include"})

# Build a DataFrame from the collected records
df_locations = pd.DataFrame(records)

# Display the DataFrame
df_locations
# Out:
#                                schemaLocation    type
# 0                      ../common/atributy.xsd  import
# 1                        ../common/common.xsd  import
# 2          ../common/doprovodne_informace.xsd  import
# 3                       ../common/extenze.xsd  import
# 4                        ../common/servis.xsd  import
# ..                                        ...     ...
# 359                  ../objekty/zed-linie.xsd  import
# 360                 ../objekty/zed-plocha.xsd  import
# 361  ../objekty/zeleznicni_prejezd-plocha.xsd  import
# 362   ../objekty/zemedelska_plocha-defbod.xsd  import
# 363   ../objekty/zemedelska_plocha-plocha.xsd  import
#
# [364 rows x 2 columns]

# %% [markdown]
# # Define a helper function to normalize paths
# Strip leading `../` segments and an optional `xsd/` prefix so that all comparisons use the same base.

# %%
from pathlib import Path

def normalize_path(p: str) -> str:
    """
    Remove any leading '../' segments and a leading 'xsd/' prefix
    from the given POSIX-style path string.
    """
    # Strip all leading "../"
    while p.startswith("../"):
        p = p[3:]
    # Remove leading "xsd/" if present
    if p.startswith("xsd/"):
        p = p[4:]
    return p

# %% [markdown]
# ## Collect all imports/includes from the main XSD
# Parse `xsd_path`, gather every `schemaLocation` from `<xs:import>` and `<xs:include>`, and normalize.

# %%
# Load and parse the primary XSD file
tree = etree.parse(str(xsd_path))

# Define the XML namespace for XSD elements
ns = {"xs": "http://www.w3.org/2001/XMLSchema"}

# Find all <xs:import> and <xs:include> elements and get their schemaLocation values
raw_imports = {
    el.get("schemaLocation")
    for tag in ("import", "include")
    for el in tree.getroot().findall(f".//xs:{tag}", namespaces=ns)
    if el.get("schemaLocation")
}
raw_imports
# Out:
# {'../common/atributy.xsd',
#  '../common/common.xsd',
#  '../common/doprovodne_informace.xsd',
#  '../common/extenze.xsd',
#  '../common/servis.xsd',
#  '../ext/gml/gml.xsd',
#  '../objekty/BP_plynovodni_site-plocha.xsd',
#  '../objekty/BP_podzemniho_zasobniku_plynu-plocha.xsd',
#  '../objekty/BP_zarizeni_PKO-plocha.xsd',
#  '../objekty/OP_drazni_stavby-plocha.xsd',
#  '../objekty/OP_elektricke_site-plocha.xsd',
#  '../objekty/OP_jaderneho_zarizeni-plocha.xsd',
#  '../objekty/OP_kolektoru_kabelovodu-plocha.xsd',
#  '../objekty/OP_leteckych_zabezpecovacich_zarizeni-plocha.xsd',
#  '../objekty/OP_letiste-plocha.xsd',
#  '../objekty/OP_objektu_kanalizace-plocha.xsd',
#  '../objekty/OP_objektu_vodovodu-plocha.xsd',
#  '../objekty/OP_plynovodni_site-plocha.xsd',
#  '../objekty/OP_podzemniho_zasobniku_plynu-plocha.xsd',
#  '../objekty/OP_pozemni_komunikace-plocha.xsd',
#  '../objekty/OP_site_EK-plocha.xsd',
#  '../objekty/OP_site_produktovodu-plocha.xsd',
#  '../objekty/OP_stanice_elektricke_site-plocha.xsd',
#  '../objekty/OP_stavby_vodni_dopravu-plocha.xsd',
#  '../objekty/OP_teplovodni_site-plocha.xsd',
#  '../objekty/OP_vodniho_dila_I_II_kategorie_hlediska_TBD-plocha.xsd',
#  '../objekty/OP_vyrobny_elektriny-plocha.xsd',
#  '../objekty/OP_zarizeni_PKO-plocha.xsd',
#  '../objekty/OP_zarizeni_odpadoveho_hospodarstvi-plocha.xsd',
#  '../objekty/TO_plynovodni_site-bod.xsd',
#  '../objekty/TO_plynovodni_site-plocha.xsd',
#  '../objekty/TO_site_EK-bod.xsd',
#  '../objekty/TO_site_EK-plocha.xsd',
#  '../objekty/TO_site_produktovodu-bod.xsd',
#  '../objekty/TO_site_produktovodu-plocha.xsd',
#  '../objekty/TO_teplovodni_site-bod.xsd',
#  '../objekty/TO_teplovodni_site-plocha.xsd',
#  '../objekty/budova-defbod.xsd',
#  '../objekty/budova-plocha.xsd',
#  '../objekty/celo_propustku-defbod.xsd',
#  '../objekty/celo_propustku-plocha.xsd',
#  '../objekty/chodnik-defbod.xsd',
#  '../objekty/chodnik-plocha.xsd',
#  '../objekty/cyklisticka_doprava_koridor_zameru-linie.xsd',
#  '../objekty/cyklisticka_doprava_koridor_zameru-plocha.xsd',
#  '../objekty/cyklisticka_doprava_misto_zameru-bod.xsd',
#  '../objekty/cyklisticka_doprava_misto_zameru-plocha.xsd',
#  '../objekty/cyklostezka-defbod.xsd',
#  '../objekty/cyklostezka-plocha.xsd',
#  '../objekty/delici_pas-defbod.xsd',
#  '../objekty/delici_pas-plocha.xsd',
#  '../objekty/dopravne_vyznamne_misto_draze-bod.xsd',
#  '../objekty/dopravne_vyznamne_misto_draze-plocha.xsd',
#  '../objekty/dopravni_ostruvek-defbod.xsd',
#  '../objekty/dopravni_ostruvek-plocha.xsd',
#  '../objekty/dopravni_uzel_silnicni_site-bod.xsd',
#  '../objekty/drazni_doprava_koridor_zameru-linie.xsd',
#  '../objekty/drazni_doprava_koridor_zameru-plocha.xsd',
#  '../objekty/drazni_doprava_misto_zameru-bod.xsd',
#  '../objekty/drazni_doprava_misto_zameru-plocha.xsd',
#  '../objekty/drobna_kulturni_stavba-bod.xsd',
#  '../objekty/drobna_kulturni_stavba-defbod.xsd',
#  '../objekty/drobna_kulturni_stavba-plocha.xsd',
#  '../objekty/drobna_sakralni_stavba-bod.xsd',
#  '../objekty/drobna_sakralni_stavba-defbod.xsd',
#  '../objekty/drobna_sakralni_stavba-plocha.xsd',
#  '../objekty/dul_lom-defbod.xsd',
#  '../objekty/dul_lom-plocha.xsd',
#  '../objekty/dvur_nadvori-defbod.xsd',
#  '../objekty/dvur_nadvori-plocha.xsd',
#  '../objekty/elektricka_sit_koridor_zameru-linie.xsd',
#  '../objekty/elektricka_sit_koridor_zameru-plocha.xsd',
#  '../objekty/elektricka_sit_misto_zameru-bod.xsd',
#  '../objekty/elektricka_sit_misto_zameru-plocha.xsd',
#  '../objekty/elektronicka_komunikace_koridor_zameru-linie.xsd',
#  '../objekty/elektronicka_komunikace_koridor_zameru-plocha.xsd',
#  '../objekty/elektronicka_komunikace_misto_zameru-bod.xsd',
#  '../objekty/elektronicka_komunikace_misto_zameru-plocha.xsd',
#  '../objekty/heliport-bod.xsd',
#  '../objekty/heliport-plocha.xsd',
#  '../objekty/hospodarsky_nevyuzivana_plocha-defbod.xsd',
#  '../objekty/hospodarsky_nevyuzivana_plocha-plocha.xsd',
#  '../objekty/hranice_budovy-linie.xsd',
#  '../objekty/hranice_dopravni_stavby_plochy-linie.xsd',
#  '../objekty/hranice_ostatni_plochy-linie.xsd',
#  '../objekty/hranice_podzemniho_objektu_ZPS-linie.xsd',
#  '../objekty/hranice_prirodniho_poloprirodniho_objektu-linie.xsd',
#  '../objekty/hranice_schodiste-linie.xsd',
#  '../objekty/hranice_stavby-linie.xsd',
#  '../objekty/hranice_udrzovane_zelene-linie.xsd',
#  '../objekty/hranice_vodniho_dila-linie.xsd',
#  '../objekty/hranice_zarizeni_kanalizacni_pripojky-linie.xsd',
#  '../objekty/hranice_zarizeni_vodovodni_pripojky-linie.xsd',
#  '../objekty/hranice_zdi-linie.xsd',
#  '../objekty/hraz-defbod.xsd',
#  '../objekty/hraz-plocha.xsd',
#  '../objekty/hrbitov-defbod.xsd',
#  '../objekty/hrbitov-plocha.xsd',
#  '../objekty/hriste-defbod.xsd',
#  '../objekty/hriste-plocha.xsd',
#  '../objekty/identicky_bod-bod.xsd',
#  '../objekty/jaderne_zarizeni-bod.xsd',
#  '../objekty/jaderne_zarizeni-plocha.xsd',
#  '../objekty/jez-defbod.xsd',
#  '../objekty/jez-plocha.xsd',
#  '../objekty/jezero-defbod.xsd',
#  '../objekty/jezero-plocha.xsd',
#  '../objekty/jina_technologicka_stavba_TI-bod.xsd',
#  '../objekty/jine_dulni_dilo_stavba-defbod.xsd',
#  '../objekty/jine_dulni_dilo_stavba-plocha.xsd',
#  '../objekty/jine_zarizeni_odstranovani_vyuzivani_sber_odpadu-bod.xsd',
#  '../objekty/jine_zarizeni_odstranovani_vyuzivani_sber_odpadu-plocha.xsd',
#  '../objekty/jine_zarizeni_staveb_TI-bod.xsd',
#  '../objekty/kanalizace_koridor_zameru-linie.xsd',
#  '../objekty/kanalizace_koridor_zameru-plocha.xsd',
#  '../objekty/kanalizace_misto_zameru-bod.xsd',
#  '../objekty/kanalizace_misto_zameru-plocha.xsd',
#  '../objekty/kolektor-linie.xsd',
#  '../objekty/komin-defbod.xsd',
#  '../objekty/komin-plocha.xsd',
#  '../objekty/les-defbod.xsd',
#  '../objekty/les-plocha.xsd',
#  '../objekty/letecka_doprava_koridor_zameru-linie.xsd',
#  '../objekty/letecka_doprava_koridor_zameru-plocha.xsd',
#  '../objekty/letecka_doprava_misto_zameru-bod.xsd',
#  '../objekty/letecka_doprava_misto_zameru-plocha.xsd',
#  '../objekty/letecka_stavba-bod.xsd',
#  '../objekty/letecka_stavba-plocha.xsd',
#  '../objekty/letiste-plocha.xsd',
#  '../objekty/manipulacni_plocha-defbod.xsd',
#  '../objekty/manipulacni_plocha-plocha.xsd',
#  '../objekty/melioracni_prikop_zlab-defbod.xsd',
#  '../objekty/melioracni_prikop_zlab-plocha.xsd',
#  '../objekty/melioracni_sachta-bod.xsd',
#  '../objekty/mostni_vaha-defbod.xsd',
#  '../objekty/mostni_vaha-plocha.xsd',
#  '../objekty/nadrz_bez_vzdouvaciho_objektu-defbod.xsd',
#  '../objekty/nadrz_bez_vzdouvaciho_objektu-plocha.xsd',
#  '../objekty/nadrz_zdrz_se_vzdouvacim_objektem-defbod.xsd',
#  '../objekty/nadrz_zdrz_se_vzdouvacim_objektem-plocha.xsd',
#  '../objekty/najezd-defbod.xsd',
#  '../objekty/najezd-plocha.xsd',
#  '../objekty/nastupiste-defbod.xsd',
#  '../objekty/nastupiste-plocha.xsd',
#  '../objekty/neidentifikovany_objekt-linie.xsd',
#  '../objekty/nosic_technickeho_zarizeni-bod.xsd',
#  '../objekty/o6-plocha.xsd',
#  '../objekty/objekt_odvodneni_stavby-bod.xsd',
#  '../objekty/objekt_odvodneni_stavby-linie.xsd',
#  '../objekty/objekt_odvodneni_stavby-plocha.xsd',
#  '../objekty/objekt_stokove_site-bod.xsd',
#  '../objekty/objekt_stokove_site-plocha.xsd',
#  '../objekty/objekt_vodovodni_site-bod.xsd',
#  '../objekty/objekt_vodovodni_site-plocha.xsd',
#  '../objekty/objekt_zarizeni_ochrane_povodnemi-bod.xsd',
#  '../objekty/objekt_zarizeni_ochrane_povodnemi-linie.xsd',
#  '../objekty/obvod_drahy-plocha.xsd',
#  '../objekty/obvod_mostu-plocha.xsd',
#  '../objekty/obvod_pozemni_komunikace-plocha.xsd',
#  '../objekty/ochranna_sachta_vrtu-bod.xsd',
#  '../objekty/odkaliste-bod.xsd',
#  '../objekty/odkaliste-plocha.xsd',
#  '../objekty/odpadove_hospodarstvi_zamer-bod.xsd',
#  '../objekty/odpadove_hospodarstvi_zamer-linie.xsd',
#  '../objekty/odpadove_hospodarstvi_zamer-plocha.xsd',
#  '../objekty/orientacni_sloupek_TI-bod.xsd',
#  '../objekty/osa_koleje_pozemni_lanove_drahy-linie.xsd',
#  '../objekty/osa_koleje_specialni_drahy-linie.xsd',
#  '../objekty/osa_koleje_tramvajove_drahy-linie.xsd',
#  '../objekty/osa_koleje_zeleznicni_trate-linie.xsd',
#  '../objekty/osa_melioracniho_prikopu_zlabu_drenu-linie.xsd',
#  '../objekty/osa_pozemni_komunikace-linie.xsd',
#  '../objekty/osa_pozemni_lanove_drahy-linie.xsd',
#  '../objekty/osa_protipovodnove_zabrany-linie.xsd',
#  '../objekty/osa_specialni_drahy-linie.xsd',
#  '../objekty/osa_tramvajove_drahy-linie.xsd',
#  '../objekty/osa_zeleznicni_trate-linie.xsd',
#  '../objekty/ostatni_zastresena_stavba-defbod.xsd',
#  '../objekty/ostatni_zastresena_stavba-plocha.xsd',
#  '../objekty/parkoviste_odstavna_plocha-defbod.xsd',
#  '../objekty/parkoviste_odstavna_plocha-plocha.xsd',
#  '../objekty/patka_deska_monolit_pilir-defbod.xsd',
#  '../objekty/patka_deska_monolit_pilir-plocha.xsd',
#  '../objekty/plavebni_komora-bod.xsd',
#  '../objekty/plavebni_komora-plocha.xsd',
#  '../objekty/plocha_mostni_konstrukce-defbod.xsd',
#  '../objekty/plocha_mostni_konstrukce-plocha.xsd',
#  '../objekty/plocha_rekultivace-defbod.xsd',
#  '../objekty/plocha_rekultivace-plocha.xsd',
#  '../objekty/plot-linie.xsd',
#  '../objekty/plynovod_koridor_zameru-linie.xsd',
#  '../objekty/plynovod_koridor_zameru-plocha.xsd',
#  '../objekty/plynovod_misto_zameru-bod.xsd',
#  '../objekty/plynovod_misto_zameru-plocha.xsd',
#  '../objekty/podezdivka-defbod.xsd',
#  '../objekty/podezdivka-plocha.xsd',
#  '../objekty/podperne_zarizeni-bod.xsd',
#  '../objekty/podrobny_bod_ZPS-bod.xsd',
#  '../objekty/podzemni_objekt_ZPS-defbod.xsd',
#  '../objekty/podzemni_objekt_ZPS-plocha.xsd',
#  '../objekty/portal_podchodu-defbod.xsd',
#  '../objekty/portal_podchodu-plocha.xsd',
#  '../objekty/portal_tunelu-defbod.xsd',
#  '../objekty/portal_tunelu-plocha.xsd',
#  '../objekty/povrchovy_znak_TI-bod.xsd',
#  '../objekty/pozemni_cast_pristavu-bod.xsd',
#  '../objekty/pozemni_cast_pristavu-plocha.xsd',
#  '../objekty/pozemni_lanova_draha-defbod.xsd',
#  '../objekty/pozemni_lanova_draha-plocha.xsd',
#  '../objekty/pridruzena_plocha_pozemni_komunikace-defbod.xsd',
#  '../objekty/pridruzena_plocha_pozemni_komunikace-plocha.xsd',
#  '../objekty/prikop_nasep_zarez_dopravni_stavby-defbod.xsd',
#  '../objekty/prikop_nasep_zarez_dopravni_stavby-plocha.xsd',
#  '../objekty/privadec_nahon_odpad-linie.xsd',
#  '../objekty/privadec_nahon_odpad-plocha.xsd',
#  '../objekty/privadec_povrchovych_vod_koridor_zameru-linie.xsd',
#  '../objekty/privadec_povrchovych_vod_koridor_zameru-plocha.xsd',
#  '../objekty/produktovod_koridor_zameru-linie.xsd',
#  '../objekty/produktovod_koridor_zameru-plocha.xsd',
#  '../objekty/produktovod_misto_zameru-bod.xsd',
#  '../objekty/produktovod_misto_zameru-plocha.xsd',
#  '../objekty/protihlukova_stena-linie.xsd',
#  '../objekty/protipovodnova_zabrana-defbod.xsd',
#  '../objekty/protipovodnova_zabrana-linie.xsd',
#  '../objekty/protipovodnova_zabrana-plocha.xsd',
#  '../objekty/protipovodnove_opatreni_koridor_zameru-linie.xsd',
#  '../objekty/protipovodnove_opatreni_koridor_zameru-plocha.xsd',
#  '../objekty/provozni_plocha_podchodu-defbod.xsd',
#  '../objekty/provozni_plocha_podchodu-plocha.xsd',
#  '../objekty/provozni_plocha_pozemni_komunikace-defbod.xsd',
#  '../objekty/provozni_plocha_pozemni_komunikace-plocha.xsd',
#  '../objekty/provozni_plocha_tunelu-defbod.xsd',
#  '../objekty/provozni_plocha_tunelu-plocha.xsd',
#  '../objekty/provozni_prostor_elektricke_site-plocha.xsd',
#  '../objekty/prubeh_jine_technologicke_stavby_TI-linie.xsd',
#  '../objekty/prubeh_propustku-linie.xsd',
#  '../objekty/prubeh_technologicke_konstrukce-linie.xsd',
#  '../objekty/rampa-defbod.xsd',
#  '../objekty/rampa-plocha.xsd',
#  '../objekty/schodiste-defbod.xsd',
#  '../objekty/schodiste-plocha.xsd',
#  '../objekty/sdilena_stavba_TI_koridor_zameru-linie.xsd',
#  '../objekty/sdilena_stavba_TI_koridor_zameru-plocha.xsd',
#  '../objekty/sdileny_objekt_TI-bod.xsd',
#  '../objekty/silnicni_doprava_koridor_zameru-linie.xsd',
#  '../objekty/silnicni_doprava_koridor_zameru-plocha.xsd',
#  '../objekty/silnicni_doprava_misto_zameru-bod.xsd',
#  '../objekty/silnicni_doprava_misto_zameru-plocha.xsd',
#  '../objekty/skladka_odpadu-bod.xsd',
#  '../objekty/skladka_odpadu-plocha.xsd',
#  '../objekty/sklenik-defbod.xsd',
#  '../objekty/sklenik-plocha.xsd',
#  '../objekty/sledovana_vodni_cesta-linie.xsd',
#  '../objekty/sledovana_vodni_cesta-plocha.xsd',
#  '../objekty/sloup_technologicke_konstrukce-bod.xsd',
#  '../objekty/souhrnna_plocha_zeleznicnich_drah-defbod.xsd',
#  '../objekty/souhrnna_plocha_zeleznicnich_drah-plocha.xsd',
#  '../objekty/spalovna-bod.xsd',
#  '../objekty/spalovna-plocha.xsd',
#  '../objekty/specialni_draha-defbod.xsd',
#  '../objekty/specialni_draha-plocha.xsd',
#  '../objekty/stanice_elektricke_site-bod.xsd',
#  '../objekty/stanice_elektricke_site-plocha.xsd',
#  '../objekty/stavba_zpevneni_povrchu-defbod.xsd',
#  '../objekty/stavba_zpevneni_povrchu-plocha.xsd',
#  '../objekty/stavebne_upravene_koryto-defbod.xsd',
#  '../objekty/stavebne_upravene_koryto-plocha.xsd',
#  '../objekty/stavebne_upraveny_vjezd_pozemek-linie.xsd',
#  '../objekty/sterkova_prehrazka-defbod.xsd',
#  '../objekty/sterkova_prehrazka-plocha.xsd',
#  '../objekty/stojan_nabijeni_vydejni-bod.xsd',
#  '../objekty/studna_verejnem_prostranstvi-bod.xsd',
#  '../objekty/stupen-bod.xsd',
#  '../objekty/stupen-defbod.xsd',
#  '../objekty/stupen-plocha.xsd',
#  '../objekty/sucha_nadrz-defbod.xsd',
#  '../objekty/sucha_nadrz-plocha.xsd',
#  '../objekty/svodidlo-linie.xsd',
#  '../objekty/technicky_kanal-linie.xsd',
#  '../objekty/teplovod_koridor_zameru-linie.xsd',
#  '../objekty/teplovod_koridor_zameru-plocha.xsd',
#  '../objekty/teplovod_misto_zameru-bod.xsd',
#  '../objekty/teplovod_misto_zameru-plocha.xsd',
#  '../objekty/terasa-defbod.xsd',
#  '../objekty/terasa-plocha.xsd',
#  '../objekty/terenni_hrana-linie.xsd',
#  '../objekty/terminal_kombinovane_dopravy_misto_zameru-bod.xsd',
#  '../objekty/terminal_kombinovane_dopravy_misto_zameru-plocha.xsd',
#  '../objekty/tramvajova_draha-defbod.xsd',
#  '../objekty/tramvajova_draha-plocha.xsd',
#  '../objekty/trasa_PKO-linie.xsd',
#  '../objekty/trasa_elektricke_site-linie.xsd',
#  '../objekty/trasa_kanalizacni_pripojky-linie.xsd',
#  '../objekty/trasa_mistni_elektricke_site-linie.xsd',
#  '../objekty/trasa_odberneho_elektrickeho_zarizeni-linie.xsd',
#  '../objekty/trasa_odberneho_plynoveho_zarizeni-linie.xsd',
#  '../objekty/trasa_plynovodni_pripojky-linie.xsd',
#  '../objekty/trasa_plynovodni_site-linie.xsd',
#  '../objekty/trasa_potrubni_posty-linie.xsd',
#  '../objekty/trasa_radioveho_smeroveho_spoje-linie.xsd',
#  '../objekty/trasa_site_EK-linie.xsd',
#  '../objekty/trasa_site_produktovodu-linie.xsd',
#  '../objekty/trasa_stokove_site-linie.xsd',
#  '../objekty/trasa_teplovodni_site-linie.xsd',
#  '../objekty/trasa_vodovodni_pripojky-linie.xsd',
#  '../objekty/trasa_vodovodni_site-linie.xsd',
#  '../objekty/udrzovana_plocha_zelene-defbod.xsd',
#  '../objekty/udrzovana_plocha_zelene-plocha.xsd',
#  '../objekty/ulozne_misto_tezebniho_odpadu-defbod.xsd',
#  '../objekty/ulozne_misto_tezebniho_odpadu-plocha.xsd',
#  '../objekty/vegetacni_misa-defbod.xsd',
#  '../objekty/vegetacni_misa-plocha.xsd',
#  '../objekty/visuta_lanova_draha-linie.xsd',
#  '../objekty/vnitrni_cleneni_budov_staveb-linie.xsd',
#  '../objekty/vnitrni_cleneni_dopravni_plochy-linie.xsd',
#  '../objekty/vodni_cast_pristavu-bod.xsd',
#  '../objekty/vodni_cast_pristavu-plocha.xsd',
#  '../objekty/vodni_doprava_koridor_zameru-linie.xsd',
#  '../objekty/vodni_doprava_koridor_zameru-plocha.xsd',
#  '../objekty/vodni_doprava_misto_zameru-bod.xsd',
#  '../objekty/vodni_doprava_misto_zameru-plocha.xsd',
#  '../objekty/vodni_tok-defbod.xsd',
#  '../objekty/vodni_tok-plocha.xsd',
#  '../objekty/vodovod_koridor_zameru-linie.xsd',
#  '../objekty/vodovod_koridor_zameru-plocha.xsd',
#  '../objekty/vodovod_misto_zameru-bod.xsd',
#  '../objekty/vodovod_misto_zameru-plocha.xsd',
#  '../objekty/vrt-bod.xsd',
#  '../objekty/vyrobna_elektriny_nad50kw-bod.xsd',
#  '../objekty/vyrobna_elektriny_nad50kw-plocha.xsd',
#  '../objekty/vyskovy_bod_terenu-bod.xsd',
#  '../objekty/vytah_v_chodniku-bod.xsd',
#  '../objekty/vzletova_pristavaci_draha-plocha.xsd',
#  '../objekty/zabradli-linie.xsd',
#  '../objekty/zahrada-defbod.xsd',
#  '../objekty/zahrada-plocha.xsd',
#  '../objekty/zahradni_bazen-defbod.xsd',
#  '../objekty/zahradni_bazen-plocha.xsd',
#  '../objekty/zarizeni_PKO-bod.xsd',
#  '../objekty/zarizeni_PKO-plocha.xsd',
#  '../objekty/zarizeni_elektricke_site-bod.xsd',
#  '../objekty/zarizeni_kanalizacni_pripojky-bod.xsd',
#  '../objekty/zarizeni_kanalizacni_pripojky-defbod.xsd',
#  '../objekty/zarizeni_kanalizacni_pripojky-plocha.xsd',
#  '../objekty/zarizeni_letecky_provoz-bod.xsd',
#  '../objekty/zarizeni_plynovodni_site-bod.xsd',
#  '../objekty/zarizeni_potrubni_posty-bod.xsd',
#  '../objekty/zarizeni_privadece-bod.xsd',
#  '../objekty/zarizeni_site_EK-bod.xsd',
#  '../objekty/zarizeni_site_produktovodu-bod.xsd',
#  '../objekty/zarizeni_site_produktovodu-plocha.xsd',
#  '../objekty/zarizeni_teplovodni_site-bod.xsd',
#  '../objekty/zarizeni_vodovodni_pripojky-bod.xsd',
#  '../objekty/zarizeni_vodovodni_pripojky-defbod.xsd',
#  '../objekty/zarizeni_vodovodni_pripojky-plocha.xsd',
#  '../objekty/zastreseni-defbod.xsd',
#  '../objekty/zastreseni-plocha.xsd',
#  '../objekty/zatrubneny_vodni_tok-linie.xsd',
#  '../objekty/zed-defbod.xsd',
#  '../objekty/zed-linie.xsd',
#  '../objekty/zed-plocha.xsd',
#  '../objekty/zeleznicni_prejezd-plocha.xsd',
#  '../objekty/zemedelska_plocha-defbod.xsd',
#  '../objekty/zemedelska_plocha-plocha.xsd'}

# %% [markdown]
# ## Cell 3: Normalize imported paths and scan output directory
# This cell normalizes each extracted schemaLocation and then recursively scans the `output_path` for all `.xsd` files, normalizing their relative POSIX paths.

# %%
# Normalize each imported schemaLocation path to remove unwanted prefixes
imported = {
    normalize_path(Path(loc).as_posix())
    for loc in raw_imports
}

# Recursively scan the output directory for all .xsd files and normalize their relative paths
all_files = {
    normalize_path(p.relative_to(output_path).as_posix())
    for p in output_path.rglob("*.xsd")
}
all_files
# Out:
# {'common/atributy.xsd',
#  'common/common.xsd',
#  'common/doprovodne_informace.xsd',
#  'common/extenze.xsd',
#  'common/servis.xsd',
#  'ext/gco/basicTypes.xsd',
#  'ext/gco/gco.xsd',
#  'ext/gco/gcoBase.xsd',
#  'ext/gmd/applicationSchema.xsd',
#  'ext/gmd/citation.xsd',
#  'ext/gmd/constraints.xsd',
#  'ext/gmd/content.xsd',
#  'ext/gmd/dataQuality.xsd',
#  'ext/gmd/distribution.xsd',
#  'ext/gmd/extent.xsd',
#  'ext/gmd/freeText.xsd',
#  'ext/gmd/gmd.xsd',
#  'ext/gmd/identification.xsd',
#  'ext/gmd/maintenance.xsd',
#  'ext/gmd/metadataApplication.xsd',
#  'ext/gmd/metadataEntity.xsd',
#  'ext/gmd/metadataExtension.xsd',
#  'ext/gmd/portrayalCatalogue.xsd',
#  'ext/gmd/referenceSystem.xsd',
#  'ext/gmd/spatialRepresentation.xsd',
#  'ext/gml/applicationSchema.xsd',
#  'ext/gml/basicTypes.xsd',
#  'ext/gml/citation.xsd',
#  'ext/gml/constraints.xsd',
#  'ext/gml/content.xsd',
#  'ext/gml/coordinateOperations.xsd',
#  'ext/gml/coordinateReferenceSystems.xsd',
#  'ext/gml/coordinateSystems.xsd',
#  'ext/gml/coverage.xsd',
#  'ext/gml/dataQuality.xsd',
#  'ext/gml/datums.xsd',
#  'ext/gml/deprecatedTypes.xsd',
#  'ext/gml/df0b471c_gml.xsd',
#  'ext/gml/dictionary.xsd',
#  'ext/gml/direction.xsd',
#  'ext/gml/distribution.xsd',
#  'ext/gml/dynamicFeature.xsd',
#  'ext/gml/extent.xsd',
#  'ext/gml/feature.xsd',
#  'ext/gml/freeText.xsd',
#  'ext/gml/geometry.xsd',
#  'ext/gml/geometryAggregates.xsd',
#  'ext/gml/geometryBasic0d1d.xsd',
#  'ext/gml/geometryBasic2d.xsd',
#  'ext/gml/geometryComplexes.xsd',
#  'ext/gml/geometryPrimitives.xsd',
#  'ext/gml/gml.xsd',
#  'ext/gml/gmlBase.xsd',
#  'ext/gml/grids.xsd',
#  'ext/gml/identification.xsd',
#  'ext/gml/maintenance.xsd',
#  'ext/gml/measures.xsd',
#  'ext/gml/metadataApplication.xsd',
#  'ext/gml/metadataEntity.xsd',
#  'ext/gml/metadataExtension.xsd',
#  'ext/gml/observation.xsd',
#  'ext/gml/portrayalCatalogue.xsd',
#  'ext/gml/referenceSystem.xsd',
#  'ext/gml/referenceSystems.xsd',
#  'ext/gml/spatialReferencing.xsd',
#  'ext/gml/spatialRepresentation.xsd',
#  'ext/gml/temporal.xsd',
#  'ext/gml/temporalObjects.xsd',
#  'ext/gml/temporalReferenceSystems.xsd',
#  'ext/gml/temporalTopology.xsd',
#  'ext/gml/topology.xsd',
#  'ext/gml/units.xsd',
#  'ext/gml/valueObjects.xsd',
#  'ext/gml/xlink.xsd',
#  'ext/gml/xml.xsd',
#  'ext/gmx/catalogues.xsd',
#  'ext/gmx/codelistItem.xsd',
#  'ext/gmx/crsItem.xsd',
#  'ext/gmx/extendedTypes.xsd',
#  'ext/gmx/gmx.xsd',
#  'ext/gmx/gmxUsage.xsd',
#  'ext/gmx/uomItem.xsd',
#  'ext/gsr/gsr.xsd',
#  'ext/gsr/spatialReferencing.xsd',
#  'ext/gss/geometry.xsd',
#  'ext/gss/gss.xsd',
#  'ext/gts/gts.xsd',
#  'ext/gts/temporalObjects.xsd',
#  'index/index_data.xsd',
#  'objekty/BP_plynovodni_site-plocha.xsd',
#  'objekty/BP_podzemniho_zasobniku_plynu-plocha.xsd',
#  'objekty/BP_zarizeni_PKO-plocha.xsd',
#  'objekty/OP_drazni_stavby-plocha.xsd',
#  'objekty/OP_elektricke_site-plocha.xsd',
#  'objekty/OP_jaderneho_zarizeni-plocha.xsd',
#  'objekty/OP_kolektoru_kabelovodu-plocha.xsd',
#  'objekty/OP_leteckych_zabezpecovacich_zarizeni-plocha.xsd',
#  'objekty/OP_letiste-plocha.xsd',
#  'objekty/OP_objektu_kanalizace-plocha.xsd',
#  'objekty/OP_objektu_vodovodu-plocha.xsd',
#  'objekty/OP_plynovodni_site-plocha.xsd',
#  'objekty/OP_podzemniho_zasobniku_plynu-plocha.xsd',
#  'objekty/OP_pozemni_komunikace-plocha.xsd',
#  'objekty/OP_site_EK-plocha.xsd',
#  'objekty/OP_site_produktovodu-plocha.xsd',
#  'objekty/OP_stanice_elektricke_site-plocha.xsd',
#  'objekty/OP_stavby_vodni_dopravu-plocha.xsd',
#  'objekty/OP_teplovodni_site-plocha.xsd',
#  'objekty/OP_vodniho_dila_I_II_kategorie_hlediska_TBD-plocha.xsd',
#  'objekty/OP_vyrobny_elektriny-plocha.xsd',
#  'objekty/OP_zarizeni_PKO-plocha.xsd',
#  'objekty/OP_zarizeni_odpadoveho_hospodarstvi-plocha.xsd',
#  'objekty/TO_plynovodni_site-bod.xsd',
#  'objekty/TO_plynovodni_site-plocha.xsd',
#  'objekty/TO_site_EK-bod.xsd',
#  'objekty/TO_site_EK-plocha.xsd',
#  'objekty/TO_site_produktovodu-bod.xsd',
#  'objekty/TO_site_produktovodu-plocha.xsd',
#  'objekty/TO_teplovodni_site-bod.xsd',
#  'objekty/TO_teplovodni_site-plocha.xsd',
#  'objekty/budova-defbod.xsd',
#  'objekty/budova-plocha.xsd',
#  'objekty/celo_propustku-defbod.xsd',
#  'objekty/celo_propustku-plocha.xsd',
#  'objekty/chodnik-defbod.xsd',
#  'objekty/chodnik-plocha.xsd',
#  'objekty/cyklisticka_doprava_koridor_zameru-linie.xsd',
#  'objekty/cyklisticka_doprava_koridor_zameru-plocha.xsd',
#  'objekty/cyklisticka_doprava_misto_zameru-bod.xsd',
#  'objekty/cyklisticka_doprava_misto_zameru-plocha.xsd',
#  'objekty/cyklostezka-defbod.xsd',
#  'objekty/cyklostezka-plocha.xsd',
#  'objekty/delici_pas-defbod.xsd',
#  'objekty/delici_pas-plocha.xsd',
#  'objekty/dopravne_vyznamne_misto_draze-bod.xsd',
#  'objekty/dopravne_vyznamne_misto_draze-plocha.xsd',
#  'objekty/dopravni_ostruvek-defbod.xsd',
#  'objekty/dopravni_ostruvek-plocha.xsd',
#  'objekty/dopravni_uzel_silnicni_site-bod.xsd',
#  'objekty/drazni_doprava_koridor_zameru-linie.xsd',
#  'objekty/drazni_doprava_koridor_zameru-plocha.xsd',
#  'objekty/drazni_doprava_misto_zameru-bod.xsd',
#  'objekty/drazni_doprava_misto_zameru-plocha.xsd',
#  'objekty/drobna_kulturni_stavba-bod.xsd',
#  'objekty/drobna_kulturni_stavba-defbod.xsd',
#  'objekty/drobna_kulturni_stavba-plocha.xsd',
#  'objekty/drobna_sakralni_stavba-bod.xsd',
#  'objekty/drobna_sakralni_stavba-defbod.xsd',
#  'objekty/drobna_sakralni_stavba-plocha.xsd',
#  'objekty/dul_lom-defbod.xsd',
#  'objekty/dul_lom-plocha.xsd',
#  'objekty/dvur_nadvori-defbod.xsd',
#  'objekty/dvur_nadvori-plocha.xsd',
#  'objekty/elektricka_sit_koridor_zameru-linie.xsd',
#  'objekty/elektricka_sit_koridor_zameru-plocha.xsd',
#  'objekty/elektricka_sit_misto_zameru-bod.xsd',
#  'objekty/elektricka_sit_misto_zameru-plocha.xsd',
#  'objekty/elektronicka_komunikace_koridor_zameru-linie.xsd',
#  'objekty/elektronicka_komunikace_koridor_zameru-plocha.xsd',
#  'objekty/elektronicka_komunikace_misto_zameru-bod.xsd',
#  'objekty/elektronicka_komunikace_misto_zameru-plocha.xsd',
#  'objekty/heliport-bod.xsd',
#  'objekty/heliport-plocha.xsd',
#  'objekty/hospodarsky_nevyuzivana_plocha-defbod.xsd',
#  'objekty/hospodarsky_nevyuzivana_plocha-plocha.xsd',
#  'objekty/hranice_budovy-linie.xsd',
#  'objekty/hranice_dopravni_stavby_plochy-linie.xsd',
#  'objekty/hranice_ostatni_plochy-linie.xsd',
#  'objekty/hranice_podzemniho_objektu_ZPS-linie.xsd',
#  'objekty/hranice_prirodniho_poloprirodniho_objektu-linie.xsd',
#  'objekty/hranice_schodiste-linie.xsd',
#  'objekty/hranice_stavby-linie.xsd',
#  'objekty/hranice_udrzovane_zelene-linie.xsd',
#  'objekty/hranice_vodniho_dila-linie.xsd',
#  'objekty/hranice_zarizeni_kanalizacni_pripojky-linie.xsd',
#  'objekty/hranice_zarizeni_vodovodni_pripojky-linie.xsd',
#  'objekty/hranice_zdi-linie.xsd',
#  'objekty/hraz-defbod.xsd',
#  'objekty/hraz-plocha.xsd',
#  'objekty/hrbitov-defbod.xsd',
#  'objekty/hrbitov-plocha.xsd',
#  'objekty/hriste-defbod.xsd',
#  'objekty/hriste-plocha.xsd',
#  'objekty/identicky_bod-bod.xsd',
#  'objekty/jaderne_zarizeni-bod.xsd',
#  'objekty/jaderne_zarizeni-plocha.xsd',
#  'objekty/jez-defbod.xsd',
#  'objekty/jez-plocha.xsd',
#  'objekty/jezero-defbod.xsd',
#  'objekty/jezero-plocha.xsd',
#  'objekty/jina_technologicka_stavba_TI-bod.xsd',
#  'objekty/jine_dulni_dilo_stavba-defbod.xsd',
#  'objekty/jine_dulni_dilo_stavba-plocha.xsd',
#  'objekty/jine_zarizeni_odstranovani_vyuzivani_sber_odpadu-bod.xsd',
#  'objekty/jine_zarizeni_odstranovani_vyuzivani_sber_odpadu-plocha.xsd',
#  'objekty/jine_zarizeni_staveb_TI-bod.xsd',
#  'objekty/kanalizace_koridor_zameru-linie.xsd',
#  'objekty/kanalizace_koridor_zameru-plocha.xsd',
#  'objekty/kanalizace_misto_zameru-bod.xsd',
#  'objekty/kanalizace_misto_zameru-plocha.xsd',
#  'objekty/kolektor-linie.xsd',
#  'objekty/komin-defbod.xsd',
#  'objekty/komin-plocha.xsd',
#  'objekty/les-defbod.xsd',
#  'objekty/les-plocha.xsd',
#  'objekty/letecka_doprava_koridor_zameru-linie.xsd',
#  'objekty/letecka_doprava_koridor_zameru-plocha.xsd',
#  'objekty/letecka_doprava_misto_zameru-bod.xsd',
#  'objekty/letecka_doprava_misto_zameru-plocha.xsd',
#  'objekty/letecka_stavba-bod.xsd',
#  'objekty/letecka_stavba-plocha.xsd',
#  'objekty/letiste-plocha.xsd',
#  'objekty/manipulacni_plocha-defbod.xsd',
#  'objekty/manipulacni_plocha-plocha.xsd',
#  'objekty/melioracni_prikop_zlab-defbod.xsd',
#  'objekty/melioracni_prikop_zlab-plocha.xsd',
#  'objekty/melioracni_sachta-bod.xsd',
#  'objekty/mostni_vaha-defbod.xsd',
#  'objekty/mostni_vaha-plocha.xsd',
#  'objekty/nadrz_bez_vzdouvaciho_objektu-defbod.xsd',
#  'objekty/nadrz_bez_vzdouvaciho_objektu-plocha.xsd',
#  'objekty/nadrz_zdrz_se_vzdouvacim_objektem-defbod.xsd',
#  'objekty/nadrz_zdrz_se_vzdouvacim_objektem-plocha.xsd',
#  'objekty/najezd-defbod.xsd',
#  'objekty/najezd-plocha.xsd',
#  'objekty/nastupiste-defbod.xsd',
#  'objekty/nastupiste-plocha.xsd',
#  'objekty/neidentifikovany_objekt-linie.xsd',
#  'objekty/nosic_technickeho_zarizeni-bod.xsd',
#  'objekty/o6-plocha.xsd',
#  'objekty/objekt_odvodneni_stavby-bod.xsd',
#  'objekty/objekt_odvodneni_stavby-linie.xsd',
#  'objekty/objekt_odvodneni_stavby-plocha.xsd',
#  'objekty/objekt_stokove_site-bod.xsd',
#  'objekty/objekt_stokove_site-plocha.xsd',
#  'objekty/objekt_vodovodni_site-bod.xsd',
#  'objekty/objekt_vodovodni_site-plocha.xsd',
#  'objekty/objekt_zarizeni_ochrane_povodnemi-bod.xsd',
#  'objekty/objekt_zarizeni_ochrane_povodnemi-linie.xsd',
#  'objekty/obvod_drahy-plocha.xsd',
#  'objekty/obvod_mostu-plocha.xsd',
#  'objekty/obvod_pozemni_komunikace-plocha.xsd',
#  'objekty/ochranna_sachta_vrtu-bod.xsd',
#  'objekty/odkaliste-bod.xsd',
#  'objekty/odkaliste-plocha.xsd',
#  'objekty/odpadove_hospodarstvi_zamer-bod.xsd',
#  'objekty/odpadove_hospodarstvi_zamer-linie.xsd',
#  'objekty/odpadove_hospodarstvi_zamer-plocha.xsd',
#  'objekty/orientacni_sloupek_TI-bod.xsd',
#  'objekty/osa_koleje_pozemni_lanove_drahy-linie.xsd',
#  'objekty/osa_koleje_specialni_drahy-linie.xsd',
#  'objekty/osa_koleje_tramvajove_drahy-linie.xsd',
#  'objekty/osa_koleje_zeleznicni_trate-linie.xsd',
#  'objekty/osa_melioracniho_prikopu_zlabu_drenu-linie.xsd',
#  'objekty/osa_pozemni_komunikace-linie.xsd',
#  'objekty/osa_pozemni_lanove_drahy-linie.xsd',
#  'objekty/osa_protipovodnove_zabrany-linie.xsd',
#  'objekty/osa_specialni_drahy-linie.xsd',
#  'objekty/osa_tramvajove_drahy-linie.xsd',
#  'objekty/osa_zeleznicni_trate-linie.xsd',
#  'objekty/ostatni_zastresena_stavba-defbod.xsd',
#  'objekty/ostatni_zastresena_stavba-plocha.xsd',
#  'objekty/parkoviste_odstavna_plocha-defbod.xsd',
#  'objekty/parkoviste_odstavna_plocha-plocha.xsd',
#  'objekty/patka_deska_monolit_pilir-defbod.xsd',
#  'objekty/patka_deska_monolit_pilir-plocha.xsd',
#  'objekty/plavebni_komora-bod.xsd',
#  'objekty/plavebni_komora-plocha.xsd',
#  'objekty/plocha_mostni_konstrukce-defbod.xsd',
#  'objekty/plocha_mostni_konstrukce-plocha.xsd',
#  'objekty/plocha_rekultivace-defbod.xsd',
#  'objekty/plocha_rekultivace-plocha.xsd',
#  'objekty/plot-linie.xsd',
#  'objekty/plynovod_koridor_zameru-linie.xsd',
#  'objekty/plynovod_koridor_zameru-plocha.xsd',
#  'objekty/plynovod_misto_zameru-bod.xsd',
#  'objekty/plynovod_misto_zameru-plocha.xsd',
#  'objekty/podezdivka-defbod.xsd',
#  'objekty/podezdivka-plocha.xsd',
#  'objekty/podperne_zarizeni-bod.xsd',
#  'objekty/podrobny_bod_ZPS-bod.xsd',
#  'objekty/podzemni_objekt_ZPS-defbod.xsd',
#  'objekty/podzemni_objekt_ZPS-plocha.xsd',
#  'objekty/portal_podchodu-defbod.xsd',
#  'objekty/portal_podchodu-plocha.xsd',
#  'objekty/portal_tunelu-defbod.xsd',
#  'objekty/portal_tunelu-plocha.xsd',
#  'objekty/povrchovy_znak_TI-bod.xsd',
#  'objekty/pozemni_cast_pristavu-bod.xsd',
#  'objekty/pozemni_cast_pristavu-plocha.xsd',
#  'objekty/pozemni_lanova_draha-defbod.xsd',
#  'objekty/pozemni_lanova_draha-plocha.xsd',
#  'objekty/pridruzena_plocha_pozemni_komunikace-defbod.xsd',
#  'objekty/pridruzena_plocha_pozemni_komunikace-plocha.xsd',
#  'objekty/prikop_nasep_zarez_dopravni_stavby-defbod.xsd',
#  'objekty/prikop_nasep_zarez_dopravni_stavby-plocha.xsd',
#  'objekty/privadec_nahon_odpad-linie.xsd',
#  'objekty/privadec_nahon_odpad-plocha.xsd',
#  'objekty/privadec_povrchovych_vod_koridor_zameru-linie.xsd',
#  'objekty/privadec_povrchovych_vod_koridor_zameru-plocha.xsd',
#  'objekty/produktovod_koridor_zameru-linie.xsd',
#  'objekty/produktovod_koridor_zameru-plocha.xsd',
#  'objekty/produktovod_misto_zameru-bod.xsd',
#  'objekty/produktovod_misto_zameru-plocha.xsd',
#  'objekty/protihlukova_stena-linie.xsd',
#  'objekty/protipovodnova_zabrana-defbod.xsd',
#  'objekty/protipovodnova_zabrana-linie.xsd',
#  'objekty/protipovodnova_zabrana-plocha.xsd',
#  'objekty/protipovodnove_opatreni_koridor_zameru-linie.xsd',
#  'objekty/protipovodnove_opatreni_koridor_zameru-plocha.xsd',
#  'objekty/provozni_plocha_podchodu-defbod.xsd',
#  'objekty/provozni_plocha_podchodu-plocha.xsd',
#  'objekty/provozni_plocha_pozemni_komunikace-defbod.xsd',
#  'objekty/provozni_plocha_pozemni_komunikace-plocha.xsd',
#  'objekty/provozni_plocha_tunelu-defbod.xsd',
#  'objekty/provozni_plocha_tunelu-plocha.xsd',
#  'objekty/provozni_prostor_elektricke_site-plocha.xsd',
#  'objekty/prubeh_jine_technologicke_stavby_TI-linie.xsd',
#  'objekty/prubeh_propustku-linie.xsd',
#  'objekty/prubeh_technologicke_konstrukce-linie.xsd',
#  'objekty/rampa-defbod.xsd',
#  'objekty/rampa-plocha.xsd',
#  'objekty/schodiste-defbod.xsd',
#  'objekty/schodiste-plocha.xsd',
#  'objekty/sdilena_stavba_TI_koridor_zameru-linie.xsd',
#  'objekty/sdilena_stavba_TI_koridor_zameru-plocha.xsd',
#  'objekty/sdileny_objekt_TI-bod.xsd',
#  'objekty/silnicni_doprava_koridor_zameru-linie.xsd',
#  'objekty/silnicni_doprava_koridor_zameru-plocha.xsd',
#  'objekty/silnicni_doprava_misto_zameru-bod.xsd',
#  'objekty/silnicni_doprava_misto_zameru-plocha.xsd',
#  'objekty/skladka_odpadu-bod.xsd',
#  'objekty/skladka_odpadu-plocha.xsd',
#  'objekty/sklenik-defbod.xsd',
#  'objekty/sklenik-plocha.xsd',
#  'objekty/sledovana_vodni_cesta-linie.xsd',
#  'objekty/sledovana_vodni_cesta-plocha.xsd',
#  'objekty/sloup_technologicke_konstrukce-bod.xsd',
#  'objekty/souhrnna_plocha_zeleznicnich_drah-defbod.xsd',
#  'objekty/souhrnna_plocha_zeleznicnich_drah-plocha.xsd',
#  'objekty/spalovna-bod.xsd',
#  'objekty/spalovna-plocha.xsd',
#  'objekty/specialni_draha-defbod.xsd',
#  'objekty/specialni_draha-plocha.xsd',
#  'objekty/stanice_elektricke_site-bod.xsd',
#  'objekty/stanice_elektricke_site-plocha.xsd',
#  'objekty/stavba_zpevneni_povrchu-defbod.xsd',
#  'objekty/stavba_zpevneni_povrchu-plocha.xsd',
#  'objekty/stavebne_upravene_koryto-defbod.xsd',
#  'objekty/stavebne_upravene_koryto-plocha.xsd',
#  'objekty/stavebne_upraveny_vjezd_pozemek-linie.xsd',
#  'objekty/sterkova_prehrazka-defbod.xsd',
#  'objekty/sterkova_prehrazka-plocha.xsd',
#  'objekty/stojan_nabijeni_vydejni-bod.xsd',
#  'objekty/studna_verejnem_prostranstvi-bod.xsd',
#  'objekty/stupen-bod.xsd',
#  'objekty/stupen-defbod.xsd',
#  'objekty/stupen-plocha.xsd',
#  'objekty/sucha_nadrz-defbod.xsd',
#  'objekty/sucha_nadrz-plocha.xsd',
#  'objekty/svodidlo-linie.xsd',
#  'objekty/technicky_kanal-linie.xsd',
#  'objekty/teplovod_koridor_zameru-linie.xsd',
#  'objekty/teplovod_koridor_zameru-plocha.xsd',
#  'objekty/teplovod_misto_zameru-bod.xsd',
#  'objekty/teplovod_misto_zameru-plocha.xsd',
#  'objekty/terasa-defbod.xsd',
#  'objekty/terasa-plocha.xsd',
#  'objekty/terenni_hrana-linie.xsd',
#  'objekty/terminal_kombinovane_dopravy_misto_zameru-bod.xsd',
#  'objekty/terminal_kombinovane_dopravy_misto_zameru-plocha.xsd',
#  'objekty/tramvajova_draha-defbod.xsd',
#  'objekty/tramvajova_draha-plocha.xsd',
#  'objekty/trasa_PKO-linie.xsd',
#  'objekty/trasa_elektricke_site-linie.xsd',
#  'objekty/trasa_kanalizacni_pripojky-linie.xsd',
#  'objekty/trasa_mistni_elektricke_site-linie.xsd',
#  'objekty/trasa_odberneho_elektrickeho_zarizeni-linie.xsd',
#  'objekty/trasa_odberneho_plynoveho_zarizeni-linie.xsd',
#  'objekty/trasa_plynovodni_pripojky-linie.xsd',
#  'objekty/trasa_plynovodni_site-linie.xsd',
#  'objekty/trasa_potrubni_posty-linie.xsd',
#  'objekty/trasa_radioveho_smeroveho_spoje-linie.xsd',
#  'objekty/trasa_site_EK-linie.xsd',
#  'objekty/trasa_site_produktovodu-linie.xsd',
#  'objekty/trasa_stokove_site-linie.xsd',
#  'objekty/trasa_teplovodni_site-linie.xsd',
#  'objekty/trasa_vodovodni_pripojky-linie.xsd',
#  'objekty/trasa_vodovodni_site-linie.xsd',
#  'objekty/udrzovana_plocha_zelene-defbod.xsd',
#  'objekty/udrzovana_plocha_zelene-plocha.xsd',
#  'objekty/ulozne_misto_tezebniho_odpadu-defbod.xsd',
#  'objekty/ulozne_misto_tezebniho_odpadu-plocha.xsd',
#  'objekty/vegetacni_misa-defbod.xsd',
#  'objekty/vegetacni_misa-plocha.xsd',
#  'objekty/visuta_lanova_draha-linie.xsd',
#  'objekty/vnitrni_cleneni_budov_staveb-linie.xsd',
#  'objekty/vnitrni_cleneni_dopravni_plochy-linie.xsd',
#  'objekty/vodni_cast_pristavu-bod.xsd',
#  'objekty/vodni_cast_pristavu-plocha.xsd',
#  'objekty/vodni_doprava_koridor_zameru-linie.xsd',
#  'objekty/vodni_doprava_koridor_zameru-plocha.xsd',
#  'objekty/vodni_doprava_misto_zameru-bod.xsd',
#  'objekty/vodni_doprava_misto_zameru-plocha.xsd',
#  'objekty/vodni_tok-defbod.xsd',
#  'objekty/vodni_tok-plocha.xsd',
#  'objekty/vodovod_koridor_zameru-linie.xsd',
#  'objekty/vodovod_koridor_zameru-plocha.xsd',
#  'objekty/vodovod_misto_zameru-bod.xsd',
#  'objekty/vodovod_misto_zameru-plocha.xsd',
#  'objekty/vrt-bod.xsd',
#  'objekty/vyrobna_elektriny_nad50kw-bod.xsd',
#  'objekty/vyrobna_elektriny_nad50kw-plocha.xsd',
#  'objekty/vyskovy_bod_terenu-bod.xsd',
#  'objekty/vytah_v_chodniku-bod.xsd',
#  'objekty/vzletova_pristavaci_draha-plocha.xsd',
#  'objekty/zabradli-linie.xsd',
#  'objekty/zahrada-defbod.xsd',
#  'objekty/zahrada-plocha.xsd',
#  'objekty/zahradni_bazen-defbod.xsd',
#  'objekty/zahradni_bazen-plocha.xsd',
#  'objekty/zarizeni_PKO-bod.xsd',
#  'objekty/zarizeni_PKO-plocha.xsd',
#  'objekty/zarizeni_elektricke_site-bod.xsd',
#  'objekty/zarizeni_kanalizacni_pripojky-bod.xsd',
#  'objekty/zarizeni_kanalizacni_pripojky-defbod.xsd',
#  'objekty/zarizeni_kanalizacni_pripojky-plocha.xsd',
#  'objekty/zarizeni_letecky_provoz-bod.xsd',
#  'objekty/zarizeni_plynovodni_site-bod.xsd',
#  'objekty/zarizeni_potrubni_posty-bod.xsd',
#  'objekty/zarizeni_privadece-bod.xsd',
#  'objekty/zarizeni_site_EK-bod.xsd',
#  'objekty/zarizeni_site_produktovodu-bod.xsd',
#  'objekty/zarizeni_site_produktovodu-plocha.xsd',
#  'objekty/zarizeni_teplovodni_site-bod.xsd',
#  'objekty/zarizeni_vodovodni_pripojky-bod.xsd',
#  'objekty/zarizeni_vodovodni_pripojky-defbod.xsd',
#  'objekty/zarizeni_vodovodni_pripojky-plocha.xsd',
#  'objekty/zastreseni-defbod.xsd',
#  'objekty/zastreseni-plocha.xsd',
#  'objekty/zatrubneny_vodni_tok-linie.xsd',
#  'objekty/zed-defbod.xsd',
#  'objekty/zed-linie.xsd',
#  'objekty/zed-plocha.xsd',
#  'objekty/zeleznicni_prejezd-plocha.xsd',
#  'objekty/zemedelska_plocha-defbod.xsd',
#  'objekty/zemedelska_plocha-plocha.xsd'}

# %% [markdown]
# ## Cell 4: Compare import list with existing files and build DataFrame
# This cell iterates over the union of imported paths and discovered files, determines each file’s status, and assembles the results into a Pandas DataFrame.

# %%
# Initialize a list to collect comparison records
records = []

# Iterate through all unique paths from imports and disk
for path in sorted(imported.union(all_files)):
    # Check if the path was imported and if it exists on disk
    in_imports     = path in imported
    exists_on_disk = path in all_files

    # Determine status: OK if both, Missing if imported but not on disk, Unreferenced otherwise
    status = (
        "OK"            if in_imports and exists_on_disk else
        "Missing"       if in_imports and not exists_on_disk else
        "Unreferenced"
    )

    # Append a record for this path
    records.append({
        "Path":      path,
        "Imported":  in_imports,
        "Exists":    exists_on_disk,
        "Status":    status
    })

# Create a DataFrame from the list of records
df_check = pd.DataFrame(records)
pd.set_option('display.max_rows', None)
pd.set_option('display.max_columns', None)
df_check
# Out:
#                                                   Path  Imported  Exists  \
# 0                                  common/atributy.xsd      True    True
# 1                                    common/common.xsd      True    True
# 2                      common/doprovodne_informace.xsd      True    True
# 3                                   common/extenze.xsd      True    True
# 4                                    common/servis.xsd      True    True
# 5                               ext/gco/basicTypes.xsd     False    True
# 6                                      ext/gco/gco.xsd     False    True
# 7                                  ext/gco/gcoBase.xsd     False    True
# 8                        ext/gmd/applicationSchema.xsd     False    True
# 9                                 ext/gmd/citation.xsd     False    True
# 10                             ext/gmd/constraints.xsd     False    True
# 11                                 ext/gmd/content.xsd     False    True
# 12                             ext/gmd/dataQuality.xsd     False    True
# 13                            ext/gmd/distribution.xsd     False    True
# 14                                  ext/gmd/extent.xsd     False    True
# 15                                ext/gmd/freeText.xsd     False    True
# 16                                     ext/gmd/gmd.xsd     False    True
# 17                          ext/gmd/identification.xsd     False    True
# 18                             ext/gmd/maintenance.xsd     False    True
# 19                     ext/gmd/metadataApplication.xsd     False    True
# 20                          ext/gmd/metadataEntity.xsd     False    True
# 21                       ext/gmd/metadataExtension.xsd     False    True
# 22                      ext/gmd/portrayalCatalogue.xsd     False    True
# 23                         ext/gmd/referenceSystem.xsd     False    True
# 24                   ext/gmd/spatialRepresentation.xsd     False    True
# 25                       ext/gml/applicationSchema.xsd     False    True
# 26                              ext/gml/basicTypes.xsd     False    True
# 27                                ext/gml/citation.xsd     False    True
# 28                             ext/gml/constraints.xsd     False    True
# 29                                 ext/gml/content.xsd     False    True
# 30                    ext/gml/coordinateOperations.xsd     False    True
# 31              ext/gml/coordinateReferenceSystems.xsd     False    True
# 32                       ext/gml/coordinateSystems.xsd     False    True
# 33                                ext/gml/coverage.xsd     False    True
# 34                             ext/gml/dataQuality.xsd     False    True
# 35                                  ext/gml/datums.xsd     False    True
# 36                         ext/gml/deprecatedTypes.xsd     False    True
# 37                            ext/gml/df0b471c_gml.xsd     False    True
# 38                              ext/gml/dictionary.xsd     False    True
# 39                               ext/gml/direction.xsd     False    True
# 40                            ext/gml/distribution.xsd     False    True
# 41                          ext/gml/dynamicFeature.xsd     False    True
# 42                                  ext/gml/extent.xsd     False    True
# 43                                 ext/gml/feature.xsd     False    True
# 44                                ext/gml/freeText.xsd     False    True
# 45                                ext/gml/geometry.xsd     False    True
# 46                      ext/gml/geometryAggregates.xsd     False    True
# 47                       ext/gml/geometryBasic0d1d.xsd     False    True
# 48                         ext/gml/geometryBasic2d.xsd     False    True
# 49                       ext/gml/geometryComplexes.xsd     False    True
# 50                      ext/gml/geometryPrimitives.xsd     False    True
# 51                                     ext/gml/gml.xsd      True    True
# 52                                 ext/gml/gmlBase.xsd     False    True
# 53                                   ext/gml/grids.xsd     False    True
# 54                          ext/gml/identification.xsd     False    True
# 55                             ext/gml/maintenance.xsd     False    True
# 56                                ext/gml/measures.xsd     False    True
# 57                     ext/gml/metadataApplication.xsd     False    True
# 58                          ext/gml/metadataEntity.xsd     False    True
# 59                       ext/gml/metadataExtension.xsd     False    True
# 60                             ext/gml/observation.xsd     False    True
# 61                      ext/gml/portrayalCatalogue.xsd     False    True
# 62                         ext/gml/referenceSystem.xsd     False    True
# 63                        ext/gml/referenceSystems.xsd     False    True
# 64                      ext/gml/spatialReferencing.xsd     False    True
# 65                   ext/gml/spatialRepresentation.xsd     False    True
# 66                                ext/gml/temporal.xsd     False    True
# 67                         ext/gml/temporalObjects.xsd     False    True
# 68                ext/gml/temporalReferenceSystems.xsd     False    True
# 69                        ext/gml/temporalTopology.xsd     False    True
# 70                                ext/gml/topology.xsd     False    True
# 71                                   ext/gml/units.xsd     False    True
# 72                            ext/gml/valueObjects.xsd     False    True
# 73                                   ext/gml/xlink.xsd     False    True
# 74                                     ext/gml/xml.xsd     False    True
# 75                              ext/gmx/catalogues.xsd     False    True
# 76                            ext/gmx/codelistItem.xsd     False    True
# 77                                 ext/gmx/crsItem.xsd     False    True
# 78                           ext/gmx/extendedTypes.xsd     False    True
# 79                                     ext/gmx/gmx.xsd     False    True
# 80                                ext/gmx/gmxUsage.xsd     False    True
# 81                                 ext/gmx/uomItem.xsd     False    True
# 82                                     ext/gsr/gsr.xsd     False    True
# 83                      ext/gsr/spatialReferencing.xsd     False    True
# 84                                ext/gss/geometry.xsd     False    True
# 85                                     ext/gss/gss.xsd     False    True
# 86                                     ext/gts/gts.xsd     False    True
# 87                         ext/gts/temporalObjects.xsd     False    True
# 88                                index/index_data.xsd     False    True
# 89               objekty/BP_plynovodni_site-plocha.xsd      True    True
# 90    objekty/BP_podzemniho_zasobniku_plynu-plocha.xsd      True    True
# 91                  objekty/BP_zarizeni_PKO-plocha.xsd      True    True
# 92                 objekty/OP_drazni_stavby-plocha.xsd      True    True
# 93               objekty/OP_elektricke_site-plocha.xsd      True    True
# 94            objekty/OP_jaderneho_zarizeni-plocha.xsd      True    True
# 95          objekty/OP_kolektoru_kabelovodu-plocha.xsd      True    True
# 96   objekty/OP_leteckych_zabezpecovacich_zarizeni-...      True    True
# 97                       objekty/OP_letiste-plocha.xsd      True    True
# 98            objekty/OP_objektu_kanalizace-plocha.xsd      True    True
# 99              objekty/OP_objektu_vodovodu-plocha.xsd      True    True
# 100              objekty/OP_plynovodni_site-plocha.xsd      True    True
# 101   objekty/OP_podzemniho_zasobniku_plynu-plocha.xsd      True    True
# 102           objekty/OP_pozemni_komunikace-plocha.xsd      True    True
# 103                      objekty/OP_site_EK-plocha.xsd      True    True
# 104            objekty/OP_site_produktovodu-plocha.xsd      True    True
# 105      objekty/OP_stanice_elektricke_site-plocha.xsd      True    True
# 106         objekty/OP_stavby_vodni_dopravu-plocha.xsd      True    True
# 107              objekty/OP_teplovodni_site-plocha.xsd      True    True
# 108  objekty/OP_vodniho_dila_I_II_kategorie_hledisk...      True    True
# 109            objekty/OP_vyrobny_elektriny-plocha.xsd      True    True
# 110                 objekty/OP_zarizeni_PKO-plocha.xsd      True    True
# 111  objekty/OP_zarizeni_odpadoveho_hospodarstvi-pl...      True    True
# 112                 objekty/TO_plynovodni_site-bod.xsd      True    True
# 113              objekty/TO_plynovodni_site-plocha.xsd      True    True
# 114                         objekty/TO_site_EK-bod.xsd      True    True
# 115                      objekty/TO_site_EK-plocha.xsd      True    True
# 116               objekty/TO_site_produktovodu-bod.xsd      True    True
# 117            objekty/TO_site_produktovodu-plocha.xsd      True    True
# 118                 objekty/TO_teplovodni_site-bod.xsd      True    True
# 119              objekty/TO_teplovodni_site-plocha.xsd      True    True
# 120                          objekty/budova-defbod.xsd      True    True
# 121                          objekty/budova-plocha.xsd      True    True
# 122                  objekty/celo_propustku-defbod.xsd      True    True
# 123                  objekty/celo_propustku-plocha.xsd      True    True
# 124                         objekty/chodnik-defbod.xsd      True    True
# 125                         objekty/chodnik-plocha.xsd      True    True
# 126  objekty/cyklisticka_doprava_koridor_zameru-lin...      True    True
# 127  objekty/cyklisticka_doprava_koridor_zameru-plo...      True    True
# 128   objekty/cyklisticka_doprava_misto_zameru-bod.xsd      True    True
# 129  objekty/cyklisticka_doprava_misto_zameru-ploch...      True    True
# 130                     objekty/cyklostezka-defbod.xsd      True    True
# 131                     objekty/cyklostezka-plocha.xsd      True    True
# 132                      objekty/delici_pas-defbod.xsd      True    True
# 133                      objekty/delici_pas-plocha.xsd      True    True
# 134      objekty/dopravne_vyznamne_misto_draze-bod.xsd      True    True
# 135   objekty/dopravne_vyznamne_misto_draze-plocha.xsd      True    True
# 136               objekty/dopravni_ostruvek-defbod.xsd      True    True
# 137               objekty/dopravni_ostruvek-plocha.xsd      True    True
# 138        objekty/dopravni_uzel_silnicni_site-bod.xsd      True    True
# 139    objekty/drazni_doprava_koridor_zameru-linie.xsd      True    True
# 140   objekty/drazni_doprava_koridor_zameru-plocha.xsd      True    True
# 141        objekty/drazni_doprava_misto_zameru-bod.xsd      True    True
# 142     objekty/drazni_doprava_misto_zameru-plocha.xsd      True    True
# 143             objekty/drobna_kulturni_stavba-bod.xsd      True    True
# 144          objekty/drobna_kulturni_stavba-defbod.xsd      True    True
# 145          objekty/drobna_kulturni_stavba-plocha.xsd      True    True
# 146             objekty/drobna_sakralni_stavba-bod.xsd      True    True
# 147          objekty/drobna_sakralni_stavba-defbod.xsd      True    True
# 148          objekty/drobna_sakralni_stavba-plocha.xsd      True    True
# 149                         objekty/dul_lom-defbod.xsd      True    True
# 150                         objekty/dul_lom-plocha.xsd      True    True
# 151                    objekty/dvur_nadvori-defbod.xsd      True    True
# 152                    objekty/dvur_nadvori-plocha.xsd      True    True
# 153    objekty/elektricka_sit_koridor_zameru-linie.xsd      True    True
# 154   objekty/elektricka_sit_koridor_zameru-plocha.xsd      True    True
# 155        objekty/elektricka_sit_misto_zameru-bod.xsd      True    True
# 156     objekty/elektricka_sit_misto_zameru-plocha.xsd      True    True
# 157  objekty/elektronicka_komunikace_koridor_zameru...      True    True
# 158  objekty/elektronicka_komunikace_koridor_zameru...      True    True
# 159  objekty/elektronicka_komunikace_misto_zameru-b...      True    True
# 160  objekty/elektronicka_komunikace_misto_zameru-p...      True    True
# 161                           objekty/heliport-bod.xsd      True    True
# 162                        objekty/heliport-plocha.xsd      True    True
# 163  objekty/hospodarsky_nevyuzivana_plocha-defbod.xsd      True    True
# 164  objekty/hospodarsky_nevyuzivana_plocha-plocha.xsd      True    True
# 165                   objekty/hranice_budovy-linie.xsd      True    True
# 166   objekty/hranice_dopravni_stavby_plochy-linie.xsd      True    True
# 167           objekty/hranice_ostatni_plochy-linie.xsd      True    True
# 168   objekty/hranice_podzemniho_objektu_ZPS-linie.xsd      True    True
# 169  objekty/hranice_prirodniho_poloprirodniho_obje...      True    True
# 170                objekty/hranice_schodiste-linie.xsd      True    True
# 171                   objekty/hranice_stavby-linie.xsd      True    True
# 172         objekty/hranice_udrzovane_zelene-linie.xsd      True    True
# 173             objekty/hranice_vodniho_dila-linie.xsd      True    True
# 174  objekty/hranice_zarizeni_kanalizacni_pripojky-...      True    True
# 175  objekty/hranice_zarizeni_vodovodni_pripojky-li...      True    True
# 176                      objekty/hranice_zdi-linie.xsd      True    True
# 177                            objekty/hraz-defbod.xsd      True    True
# 178                            objekty/hraz-plocha.xsd      True    True
# 179                         objekty/hrbitov-defbod.xsd      True    True
# 180                         objekty/hrbitov-plocha.xsd      True    True
# 181                          objekty/hriste-defbod.xsd      True    True
# 182                          objekty/hriste-plocha.xsd      True    True
# 183                      objekty/identicky_bod-bod.xsd      True    True
# 184                   objekty/jaderne_zarizeni-bod.xsd      True    True
# 185                objekty/jaderne_zarizeni-plocha.xsd      True    True
# 186                             objekty/jez-defbod.xsd      True    True
# 187                             objekty/jez-plocha.xsd      True    True
# 188                          objekty/jezero-defbod.xsd      True    True
# 189                          objekty/jezero-plocha.xsd      True    True
# 190       objekty/jina_technologicka_stavba_TI-bod.xsd      True    True
# 191          objekty/jine_dulni_dilo_stavba-defbod.xsd      True    True
# 192          objekty/jine_dulni_dilo_stavba-plocha.xsd      True    True
# 193  objekty/jine_zarizeni_odstranovani_vyuzivani_s...      True    True
# 194  objekty/jine_zarizeni_odstranovani_vyuzivani_s...      True    True
# 195            objekty/jine_zarizeni_staveb_TI-bod.xsd      True    True
# 196        objekty/kanalizace_koridor_zameru-linie.xsd      True    True
# 197       objekty/kanalizace_koridor_zameru-plocha.xsd      True    True
# 198            objekty/kanalizace_misto_zameru-bod.xsd      True    True
# 199         objekty/kanalizace_misto_zameru-plocha.xsd      True    True
# 200                         objekty/kolektor-linie.xsd      True    True
# 201                           objekty/komin-defbod.xsd      True    True
# 202                           objekty/komin-plocha.xsd      True    True
# 203                             objekty/les-defbod.xsd      True    True
# 204                             objekty/les-plocha.xsd      True    True
# 205   objekty/letecka_doprava_koridor_zameru-linie.xsd      True    True
# 206  objekty/letecka_doprava_koridor_zameru-plocha.xsd      True    True
# 207       objekty/letecka_doprava_misto_zameru-bod.xsd      True    True
# 208    objekty/letecka_doprava_misto_zameru-plocha.xsd      True    True
# 209                     objekty/letecka_stavba-bod.xsd      True    True
# 210                  objekty/letecka_stavba-plocha.xsd      True    True
# 211                         objekty/letiste-plocha.xsd      True    True
# 212              objekty/manipulacni_plocha-defbod.xsd      True    True
# 213              objekty/manipulacni_plocha-plocha.xsd      True    True
# 214          objekty/melioracni_prikop_zlab-defbod.xsd      True    True
# 215          objekty/melioracni_prikop_zlab-plocha.xsd      True    True
# 216                  objekty/melioracni_sachta-bod.xsd      True    True
# 217                     objekty/mostni_vaha-defbod.xsd      True    True
# 218                     objekty/mostni_vaha-plocha.xsd      True    True
# 219   objekty/nadrz_bez_vzdouvaciho_objektu-defbod.xsd      True    True
# 220   objekty/nadrz_bez_vzdouvaciho_objektu-plocha.xsd      True    True
# 221  objekty/nadrz_zdrz_se_vzdouvacim_objektem-defb...      True    True
# 222  objekty/nadrz_zdrz_se_vzdouvacim_objektem-ploc...      True    True
# 223                          objekty/najezd-defbod.xsd      True    True
# 224                          objekty/najezd-plocha.xsd      True    True
# 225                      objekty/nastupiste-defbod.xsd      True    True
# 226                      objekty/nastupiste-plocha.xsd      True    True
# 227          objekty/neidentifikovany_objekt-linie.xsd      True    True
# 228         objekty/nosic_technickeho_zarizeni-bod.xsd      True    True
# 229                              objekty/o6-plocha.xsd      True    True
# 230            objekty/objekt_odvodneni_stavby-bod.xsd      True    True
# 231          objekty/objekt_odvodneni_stavby-linie.xsd      True    True
# 232         objekty/objekt_odvodneni_stavby-plocha.xsd      True    True
# 233                objekty/objekt_stokove_site-bod.xsd      True    True
# 234             objekty/objekt_stokove_site-plocha.xsd      True    True
# 235              objekty/objekt_vodovodni_site-bod.xsd      True    True
# 236           objekty/objekt_vodovodni_site-plocha.xsd      True    True
# 237  objekty/objekt_zarizeni_ochrane_povodnemi-bod.xsd      True    True
# 238  objekty/objekt_zarizeni_ochrane_povodnemi-lini...      True    True
# 239                     objekty/obvod_drahy-plocha.xsd      True    True
# 240                     objekty/obvod_mostu-plocha.xsd      True    True
# 241        objekty/obvod_pozemni_komunikace-plocha.xsd      True    True
# 242               objekty/ochranna_sachta_vrtu-bod.xsd      True    True
# 243                          objekty/odkaliste-bod.xsd      True    True
# 244                       objekty/odkaliste-plocha.xsd      True    True
# 245        objekty/odpadove_hospodarstvi_zamer-bod.xsd      True    True
# 246      objekty/odpadove_hospodarstvi_zamer-linie.xsd      True    True
# 247     objekty/odpadove_hospodarstvi_zamer-plocha.xsd      True    True
# 248              objekty/orientacni_sloupek_TI-bod.xsd      True    True
# 249  objekty/osa_koleje_pozemni_lanove_drahy-linie.xsd      True    True
# 250       objekty/osa_koleje_specialni_drahy-linie.xsd      True    True
# 251      objekty/osa_koleje_tramvajove_drahy-linie.xsd      True    True
# 252      objekty/osa_koleje_zeleznicni_trate-linie.xsd      True    True
# 253  objekty/osa_melioracniho_prikopu_zlabu_drenu-l...      True    True
# 254           objekty/osa_pozemni_komunikace-linie.xsd      True    True
# 255         objekty/osa_pozemni_lanove_drahy-linie.xsd      True    True
# 256       objekty/osa_protipovodnove_zabrany-linie.xsd      True    True
# 257              objekty/osa_specialni_drahy-linie.xsd      True    True
# 258             objekty/osa_tramvajove_drahy-linie.xsd      True    True
# 259             objekty/osa_zeleznicni_trate-linie.xsd      True    True
# 260       objekty/ostatni_zastresena_stavba-defbod.xsd      True    True
# 261       objekty/ostatni_zastresena_stavba-plocha.xsd      True    True
# 262      objekty/parkoviste_odstavna_plocha-defbod.xsd      True    True
# 263      objekty/parkoviste_odstavna_plocha-plocha.xsd      True    True
# 264       objekty/patka_deska_monolit_pilir-defbod.xsd      True    True
# 265       objekty/patka_deska_monolit_pilir-plocha.xsd      True    True
# 266                    objekty/plavebni_komora-bod.xsd      True    True
# 267                 objekty/plavebni_komora-plocha.xsd      True    True
# 268        objekty/plocha_mostni_konstrukce-defbod.xsd      True    True
# 269        objekty/plocha_mostni_konstrukce-plocha.xsd      True    True
# 270              objekty/plocha_rekultivace-defbod.xsd      True    True
# 271              objekty/plocha_rekultivace-plocha.xsd      True    True
# 272                             objekty/plot-linie.xsd      True    True
# 273          objekty/plynovod_koridor_zameru-linie.xsd      True    True
# 274         objekty/plynovod_koridor_zameru-plocha.xsd      True    True
# 275              objekty/plynovod_misto_zameru-bod.xsd      True    True
# 276           objekty/plynovod_misto_zameru-plocha.xsd      True    True
# 277                      objekty/podezdivka-defbod.xsd      True    True
# 278                      objekty/podezdivka-plocha.xsd      True    True
# 279                  objekty/podperne_zarizeni-bod.xsd      True    True
# 280                   objekty/podrobny_bod_ZPS-bod.xsd      True    True
# 281             objekty/podzemni_objekt_ZPS-defbod.xsd      True    True
# 282             objekty/podzemni_objekt_ZPS-plocha.xsd      True    True
# 283                 objekty/portal_podchodu-defbod.xsd      True    True
# 284                 objekty/portal_podchodu-plocha.xsd      True    True
# 285                   objekty/portal_tunelu-defbod.xsd      True    True
# 286                   objekty/portal_tunelu-plocha.xsd      True    True
# 287                  objekty/povrchovy_znak_TI-bod.xsd      True    True
# 288              objekty/pozemni_cast_pristavu-bod.xsd      True    True
# 289           objekty/pozemni_cast_pristavu-plocha.xsd      True    True
# 290            objekty/pozemni_lanova_draha-defbod.xsd      True    True
# 291            objekty/pozemni_lanova_draha-plocha.xsd      True    True
# 292  objekty/pridruzena_plocha_pozemni_komunikace-d...      True    True
# 293  objekty/pridruzena_plocha_pozemni_komunikace-p...      True    True
# 294  objekty/prikop_nasep_zarez_dopravni_stavby-def...      True    True
# 295  objekty/prikop_nasep_zarez_dopravni_stavby-plo...      True    True
# 296             objekty/privadec_nahon_odpad-linie.xsd      True    True
# 297            objekty/privadec_nahon_odpad-plocha.xsd      True    True
# 298  objekty/privadec_povrchovych_vod_koridor_zamer...      True    True
# 299  objekty/privadec_povrchovych_vod_koridor_zamer...      True    True
# 300       objekty/produktovod_koridor_zameru-linie.xsd      True    True
# 301      objekty/produktovod_koridor_zameru-plocha.xsd      True    True
# 302           objekty/produktovod_misto_zameru-bod.xsd      True    True
# 303        objekty/produktovod_misto_zameru-plocha.xsd      True    True
# 304               objekty/protihlukova_stena-linie.xsd      True    True
# 305          objekty/protipovodnova_zabrana-defbod.xsd      True    True
# 306           objekty/protipovodnova_zabrana-linie.xsd      True    True
# 307          objekty/protipovodnova_zabrana-plocha.xsd      True    True
# 308  objekty/protipovodnove_opatreni_koridor_zameru...      True    True
# 309  objekty/protipovodnove_opatreni_koridor_zameru...      True    True
# 310        objekty/provozni_plocha_podchodu-defbod.xsd      True    True
# 311        objekty/provozni_plocha_podchodu-plocha.xsd      True    True
# 312  objekty/provozni_plocha_pozemni_komunikace-def...      True    True
# 313  objekty/provozni_plocha_pozemni_komunikace-plo...      True    True
# 314          objekty/provozni_plocha_tunelu-defbod.xsd      True    True
# 315          objekty/provozni_plocha_tunelu-plocha.xsd      True    True
# 316  objekty/provozni_prostor_elektricke_site-ploch...      True    True
# 317  objekty/prubeh_jine_technologicke_stavby_TI-li...      True    True
# 318                 objekty/prubeh_propustku-linie.xsd      True    True
# 319  objekty/prubeh_technologicke_konstrukce-linie.xsd      True    True
# 320                           objekty/rampa-defbod.xsd      True    True
# 321                           objekty/rampa-plocha.xsd      True    True
# 322                       objekty/schodiste-defbod.xsd      True    True
# 323                       objekty/schodiste-plocha.xsd      True    True
# 324  objekty/sdilena_stavba_TI_koridor_zameru-linie...      True    True
# 325  objekty/sdilena_stavba_TI_koridor_zameru-ploch...      True    True
# 326                  objekty/sdileny_objekt_TI-bod.xsd      True    True
# 327  objekty/silnicni_doprava_koridor_zameru-linie.xsd      True    True
# 328  objekty/silnicni_doprava_koridor_zameru-plocha...      True    True
# 329      objekty/silnicni_doprava_misto_zameru-bod.xsd      True    True
# 330   objekty/silnicni_doprava_misto_zameru-plocha.xsd      True    True
# 331                     objekty/skladka_odpadu-bod.xsd      True    True
# 332                  objekty/skladka_odpadu-plocha.xsd      True    True
# 333                         objekty/sklenik-defbod.xsd      True    True
# 334                         objekty/sklenik-plocha.xsd      True    True
# 335            objekty/sledovana_vodni_cesta-linie.xsd      True    True
# 336           objekty/sledovana_vodni_cesta-plocha.xsd      True    True
# 337     objekty/sloup_technologicke_konstrukce-bod.xsd      True    True
# 338  objekty/souhrnna_plocha_zeleznicnich_drah-defb...      True    True
# 339  objekty/souhrnna_plocha_zeleznicnich_drah-ploc...      True    True
# 340                           objekty/spalovna-bod.xsd      True    True
# 341                        objekty/spalovna-plocha.xsd      True    True
# 342                 objekty/specialni_draha-defbod.xsd      True    True
# 343                 objekty/specialni_draha-plocha.xsd      True    True
# 344            objekty/stanice_elektricke_site-bod.xsd      True    True
# 345         objekty/stanice_elektricke_site-plocha.xsd      True    True
# 346         objekty/stavba_zpevneni_povrchu-defbod.xsd      True    True
# 347         objekty/stavba_zpevneni_povrchu-plocha.xsd      True    True
# 348        objekty/stavebne_upravene_koryto-defbod.xsd      True    True
# 349        objekty/stavebne_upravene_koryto-plocha.xsd      True    True
# 350  objekty/stavebne_upraveny_vjezd_pozemek-linie.xsd      True    True
# 351              objekty/sterkova_prehrazka-defbod.xsd      True    True
# 352              objekty/sterkova_prehrazka-plocha.xsd      True    True
# 353            objekty/stojan_nabijeni_vydejni-bod.xsd      True    True
# 354       objekty/studna_verejnem_prostranstvi-bod.xsd      True    True
# 355                             objekty/stupen-bod.xsd      True    True
# 356                          objekty/stupen-defbod.xsd      True    True
# 357                          objekty/stupen-plocha.xsd      True    True
# 358                     objekty/sucha_nadrz-defbod.xsd      True    True
# 359                     objekty/sucha_nadrz-plocha.xsd      True    True
# 360                         objekty/svodidlo-linie.xsd      True    True
# 361                  objekty/technicky_kanal-linie.xsd      True    True
# 362          objekty/teplovod_koridor_zameru-linie.xsd      True    True
# 363         objekty/teplovod_koridor_zameru-plocha.xsd      True    True
# 364              objekty/teplovod_misto_zameru-bod.xsd      True    True
# 365           objekty/teplovod_misto_zameru-plocha.xsd      True    True
# 366                          objekty/terasa-defbod.xsd      True    True
# 367                          objekty/terasa-plocha.xsd      True    True
# 368                    objekty/terenni_hrana-linie.xsd      True    True
# 369  objekty/terminal_kombinovane_dopravy_misto_zam...      True    True
# 370  objekty/terminal_kombinovane_dopravy_misto_zam...      True    True
# 371                objekty/tramvajova_draha-defbod.xsd      True    True
# 372                objekty/tramvajova_draha-plocha.xsd      True    True
# 373                        objekty/trasa_PKO-linie.xsd      True    True
# 374            objekty/trasa_elektricke_site-linie.xsd      True    True
# 375       objekty/trasa_kanalizacni_pripojky-linie.xsd      True    True
# 376     objekty/trasa_mistni_elektricke_site-linie.xsd      True    True
# 377  objekty/trasa_odberneho_elektrickeho_zarizeni-...      True    True
# 378  objekty/trasa_odberneho_plynoveho_zarizeni-lin...      True    True
# 379        objekty/trasa_plynovodni_pripojky-linie.xsd      True    True
# 380            objekty/trasa_plynovodni_site-linie.xsd      True    True
# 381             objekty/trasa_potrubni_posty-linie.xsd      True    True
# 382  objekty/trasa_radioveho_smeroveho_spoje-linie.xsd      True    True
# 383                    objekty/trasa_site_EK-linie.xsd      True    True
# 384          objekty/trasa_site_produktovodu-linie.xsd      True    True
# 385               objekty/trasa_stokove_site-linie.xsd      True    True
# 386            objekty/trasa_teplovodni_site-linie.xsd      True    True
# 387         objekty/trasa_vodovodni_pripojky-linie.xsd      True    True
# 388             objekty/trasa_vodovodni_site-linie.xsd      True    True
# 389         objekty/udrzovana_plocha_zelene-defbod.xsd      True    True
# 390         objekty/udrzovana_plocha_zelene-plocha.xsd      True    True
# 391   objekty/ulozne_misto_tezebniho_odpadu-defbod.xsd      True    True
# 392   objekty/ulozne_misto_tezebniho_odpadu-plocha.xsd      True    True
# 393                  objekty/vegetacni_misa-defbod.xsd      True    True
# 394                  objekty/vegetacni_misa-plocha.xsd      True    True
# 395              objekty/visuta_lanova_draha-linie.xsd      True    True
# 396     objekty/vnitrni_cleneni_budov_staveb-linie.xsd      True    True
# 397  objekty/vnitrni_cleneni_dopravni_plochy-linie.xsd      True    True
# 398                objekty/vodni_cast_pristavu-bod.xsd      True    True
# 399             objekty/vodni_cast_pristavu-plocha.xsd      True    True
# 400     objekty/vodni_doprava_koridor_zameru-linie.xsd      True    True
# 401    objekty/vodni_doprava_koridor_zameru-plocha.xsd      True    True
# 402         objekty/vodni_doprava_misto_zameru-bod.xsd      True    True
# 403      objekty/vodni_doprava_misto_zameru-plocha.xsd      True    True
# 404                       objekty/vodni_tok-defbod.xsd      True    True
# 405                       objekty/vodni_tok-plocha.xsd      True    True
# 406           objekty/vodovod_koridor_zameru-linie.xsd      True    True
# 407          objekty/vodovod_koridor_zameru-plocha.xsd      True    True
# 408               objekty/vodovod_misto_zameru-bod.xsd      True    True
# 409            objekty/vodovod_misto_zameru-plocha.xsd      True    True
# 410                                objekty/vrt-bod.xsd      True    True
# 411          objekty/vyrobna_elektriny_nad50kw-bod.xsd      True    True
# 412       objekty/vyrobna_elektriny_nad50kw-plocha.xsd      True    True
# 413                 objekty/vyskovy_bod_terenu-bod.xsd      True    True
# 414                   objekty/vytah_v_chodniku-bod.xsd      True    True
# 415       objekty/vzletova_pristavaci_draha-plocha.xsd      True    True
# 416                         objekty/zabradli-linie.xsd      True    True
# 417                         objekty/zahrada-defbod.xsd      True    True
# 418                         objekty/zahrada-plocha.xsd      True    True
# 419                  objekty/zahradni_bazen-defbod.xsd      True    True
# 420                  objekty/zahradni_bazen-plocha.xsd      True    True
# 421                       objekty/zarizeni_PKO-bod.xsd      True    True
# 422                    objekty/zarizeni_PKO-plocha.xsd      True    True
# 423           objekty/zarizeni_elektricke_site-bod.xsd      True    True
# 424      objekty/zarizeni_kanalizacni_pripojky-bod.xsd      True    True
# 425   objekty/zarizeni_kanalizacni_pripojky-defbod.xsd      True    True
# 426   objekty/zarizeni_kanalizacni_pripojky-plocha.xsd      True    True
# 427            objekty/zarizeni_letecky_provoz-bod.xsd      True    True
# 428           objekty/zarizeni_plynovodni_site-bod.xsd      True    True
# 429            objekty/zarizeni_potrubni_posty-bod.xsd      True    True
# 430                 objekty/zarizeni_privadece-bod.xsd      True    True
# 431                   objekty/zarizeni_site_EK-bod.xsd      True    True
# 432         objekty/zarizeni_site_produktovodu-bod.xsd      True    True
# 433      objekty/zarizeni_site_produktovodu-plocha.xsd      True    True
# 434           objekty/zarizeni_teplovodni_site-bod.xsd      True    True
# 435        objekty/zarizeni_vodovodni_pripojky-bod.xsd      True    True
# 436     objekty/zarizeni_vodovodni_pripojky-defbod.xsd      True    True
# 437     objekty/zarizeni_vodovodni_pripojky-plocha.xsd      True    True
# 438                      objekty/zastreseni-defbod.xsd      True    True
# 439                      objekty/zastreseni-plocha.xsd      True    True
# 440             objekty/zatrubneny_vodni_tok-linie.xsd      True    True
# 441                             objekty/zed-defbod.xsd      True    True
# 442                              objekty/zed-linie.xsd      True    True
# 443                             objekty/zed-plocha.xsd      True    True
# 444              objekty/zeleznicni_prejezd-plocha.xsd      True    True
# 445               objekty/zemedelska_plocha-defbod.xsd      True    True
# 446               objekty/zemedelska_plocha-plocha.xsd      True    True
#
#            Status
# 0              OK
# 1              OK
# 2              OK
# 3              OK
# 4              OK
# 5    Unreferenced
# 6    Unreferenced
# 7    Unreferenced
# 8    Unreferenced
# 9    Unreferenced
# 10   Unreferenced
# 11   Unreferenced
# 12   Unreferenced
# 13   Unreferenced
# 14   Unreferenced
# 15   Unreferenced
# 16   Unreferenced
# 17   Unreferenced
# 18   Unreferenced
# 19   Unreferenced
# 20   Unreferenced
# 21   Unreferenced
# 22   Unreferenced
# 23   Unreferenced
# 24   Unreferenced
# 25   Unreferenced
# 26   Unreferenced
# 27   Unreferenced
# 28   Unreferenced
# 29   Unreferenced
# 30   Unreferenced
# 31   Unreferenced
# 32   Unreferenced
# 33   Unreferenced
# 34   Unreferenced
# 35   Unreferenced
# 36   Unreferenced
# 37   Unreferenced
# 38   Unreferenced
# 39   Unreferenced
# 40   Unreferenced
# 41   Unreferenced
# 42   Unreferenced
# 43   Unreferenced
# 44   Unreferenced
# 45   Unreferenced
# 46   Unreferenced
# 47   Unreferenced
# 48   Unreferenced
# 49   Unreferenced
# 50   Unreferenced
# 51             OK
# 52   Unreferenced
# 53   Unreferenced
# 54   Unreferenced
# 55   Unreferenced
# 56   Unreferenced
# 57   Unreferenced
# 58   Unreferenced
# 59   Unreferenced
# 60   Unreferenced
# 61   Unreferenced
# 62   Unreferenced
# 63   Unreferenced
# 64   Unreferenced
# 65   Unreferenced
# 66   Unreferenced
# 67   Unreferenced
# 68   Unreferenced
# 69   Unreferenced
# 70   Unreferenced
# 71   Unreferenced
# 72   Unreferenced
# 73   Unreferenced
# 74   Unreferenced
# 75   Unreferenced
# 76   Unreferenced
# 77   Unreferenced
# 78   Unreferenced
# 79   Unreferenced
# 80   Unreferenced
# 81   Unreferenced
# 82   Unreferenced
# 83   Unreferenced
# 84   Unreferenced
# 85   Unreferenced
# 86   Unreferenced
# 87   Unreferenced
# 88   Unreferenced
# 89             OK
# 90             OK
# 91             OK
# 92             OK
# 93             OK
# 94             OK
# 95             OK
# 96             OK
# 97             OK
# 98             OK
# 99             OK
# 100            OK
# 101            OK
# 102            OK
# 103            OK
# 104            OK
# 105            OK
# 106            OK
# 107            OK
# 108            OK
# 109            OK
# 110            OK
# 111            OK
# 112            OK
# 113            OK
# 114            OK
# 115            OK
# 116            OK
# 117            OK
# 118            OK
# 119            OK
# 120            OK
# 121            OK
# 122            OK
# 123            OK
# 124            OK
# 125            OK
# 126            OK
# 127            OK
# 128            OK
# 129            OK
# 130            OK
# 131            OK
# 132            OK
# 133            OK
# 134            OK
# 135            OK
# 136            OK
# 137            OK
# 138            OK
# 139            OK
# 140            OK
# 141            OK
# 142            OK
# 143            OK
# 144            OK
# 145            OK
# 146            OK
# 147            OK
# 148            OK
# 149            OK
# 150            OK
# 151            OK
# 152            OK
# 153            OK
# 154            OK
# 155            OK
# 156            OK
# 157            OK
# 158            OK
# 159            OK
# 160            OK
# 161            OK
# 162            OK
# 163            OK
# 164            OK
# 165            OK
# 166            OK
# 167            OK
# 168            OK
# 169            OK
# 170            OK
# 171            OK
# 172            OK
# 173            OK
# 174            OK
# 175            OK
# 176            OK
# 177            OK
# 178            OK
# 179            OK
# 180            OK
# 181            OK
# 182            OK
# 183            OK
# 184            OK
# 185            OK
# 186            OK
# 187            OK
# 188            OK
# 189            OK
# 190            OK
# 191            OK
# 192            OK
# 193            OK
# 194            OK
# 195            OK
# 196            OK
# 197            OK
# 198            OK
# 199            OK
# 200            OK
# 201            OK
# 202            OK
# 203            OK
# 204            OK
# 205            OK
# 206            OK
# 207            OK
# 208            OK
# 209            OK
# 210            OK
# 211            OK
# 212            OK
# 213            OK
# 214            OK
# 215            OK
# 216            OK
# 217            OK
# 218            OK
# 219            OK
# 220            OK
# 221            OK
# 222            OK
# 223            OK
# 224            OK
# 225            OK
# 226            OK
# 227            OK
# 228            OK
# 229            OK
# 230            OK
# 231            OK
# 232            OK
# 233            OK
# 234            OK
# 235            OK
# 236            OK
# 237            OK
# 238            OK
# 239            OK
# 240            OK
# 241            OK
# 242            OK
# 243            OK
# 244            OK
# 245            OK
# 246            OK
# 247            OK
# 248            OK
# 249            OK
# 250            OK
# 251            OK
# 252            OK
# 253            OK
# 254            OK
# 255            OK
# 256            OK
# 257            OK
# 258            OK
# 259            OK
# 260            OK
# 261            OK
# 262            OK
# 263            OK
# 264            OK
# 265            OK
# 266            OK
# 267            OK
# 268            OK
# 269            OK
# 270            OK
# 271            OK
# 272            OK
# 273            OK
# 274            OK
# 275            OK
# 276            OK
# 277            OK
# 278            OK
# 279            OK
# 280            OK
# 281            OK
# 282            OK
# 283            OK
# 284            OK
# 285            OK
# 286            OK
# 287            OK
# 288            OK
# 289            OK
# 290            OK
# 291            OK
# 292            OK
# 293            OK
# 294            OK
# 295            OK
# 296            OK
# 297            OK
# 298            OK
# 299            OK
# 300            OK
# 301            OK
# 302            OK
# 303            OK
# 304            OK
# 305            OK
# 306            OK
# 307            OK
# 308            OK
# 309            OK
# 310            OK
# 311            OK
# 312            OK
# 313            OK
# 314            OK
# 315            OK
# 316            OK
# 317            OK
# 318            OK
# 319            OK
# 320            OK
# 321            OK
# 322            OK
# 323            OK
# 324            OK
# 325            OK
# 326            OK
# 327            OK
# 328            OK
# 329            OK
# 330            OK
# 331            OK
# 332            OK
# 333            OK
# 334            OK
# 335            OK
# 336            OK
# 337            OK
# 338            OK
# 339            OK
# 340            OK
# 341            OK
# 342            OK
# 343            OK
# 344            OK
# 345            OK
# 346            OK
# 347            OK
# 348            OK
# 349            OK
# 350            OK
# 351            OK
# 352            OK
# 353            OK
# 354            OK
# 355            OK
# 356            OK
# 357            OK
# 358            OK
# 359            OK
# 360            OK
# 361            OK
# 362            OK
# 363            OK
# 364            OK
# 365            OK
# 366            OK
# 367            OK
# 368            OK
# 369            OK
# 370            OK
# 371            OK
# 372            OK
# 373            OK
# 374            OK
# 375            OK
# 376            OK
# 377            OK
# 378            OK
# 379            OK
# 380            OK
# 381            OK
# 382            OK
# 383            OK
# 384            OK
# 385            OK
# 386            OK
# 387            OK
# 388            OK
# 389            OK
# 390            OK
# 391            OK
# 392            OK
# 393            OK
# 394            OK
# 395            OK
# 396            OK
# 397            OK
# 398            OK
# 399            OK
# 400            OK
# 401            OK
# 402            OK
# 403            OK
# 404            OK
# 405            OK
# 406            OK
# 407            OK
# 408            OK
# 409            OK
# 410            OK
# 411            OK
# 412            OK
# 413            OK
# 414            OK
# 415            OK
# 416            OK
# 417            OK
# 418            OK
# 419            OK
# 420            OK
# 421            OK
# 422            OK
# 423            OK
# 424            OK
# 425            OK
# 426            OK
# 427            OK
# 428            OK
# 429            OK
# 430            OK
# 431            OK
# 432            OK
# 433            OK
# 434            OK
# 435            OK
# 436            OK
# 437            OK
# 438            OK
# 439            OK
# 440            OK
# 441            OK
# 442            OK
# 443            OK
# 444            OK
# 445            OK
# 446            OK
